# %% [markdown]
# <div align="center">
#
#   # Quantum Convolutional Neural Networks<br>for High-Energy Physics Analysis at the LHC
#
# <a href="https://gist.github.com/eraraya-ricardo/8391f6bdae596e82fe0260c215c5ab8c" target="_blank"><img src="https://img.shields.io/badge/Google%20Summer%20of%20Code-2021-fbbc05?style=flat&logo=data%3Aimage%2Fpng%3Bbase64%2CiVBORw0KGgoAAAANSUhEUgAAAGQAAABkCAMAAABHPGVmAAAALVBMVEVHcEz7vQD7vQD8vQD7vQD8vQD7vQD8vQD8vQD7vQD7vQD8vQD7vQD7vQD7vQAgxtLpAAAADnRSTlMAZvVQ6QrVPhl6oSmHvzL6LQUAAASGSURBVHjatdnZdusgDAVQELMY%2Fv9zb2%2Bwc%2BIKDzQLvTXB3gYBFqmaDVeKU4sCBlFyy43WqLjlBpR1BpR1BpR1xjoFxmIFBpSVBpSVBpSVBpSVBpQ1xvdK1oPgblhfOWltjNaJq7ddYT2IfImYJqMDrENUChGDZn%2FWQ%2FMHxBcD4BMyBc5XCHkNQTq60vfIgXAx5xByju6T8V8itsT3%2FUPi6r39Ce8rp%2FCWYrHfIDXs95FZJs%2FvTob6Z4T2buQE4eikvHeG%2FoZY7TpRfDsNWzrjtP0L4s12NYhh%2BO1ZjJ9HfOjdYGo3QZx7YvwEAgOPdx3eQJlArMFA3wXSZ%2BwMQvplJGoPY6sqNU0gxcGYUVx5jtSIx3oS6HysTxEbMMDPAmkM9iFSXnPXt8nwuQ%2FYI8TH%2F425TQe7%2FnBPEH2bECI6T4t%2Bgvh4N1istR50FJdeIX1Ek%2FqJdGGQOWmAa4u7rn18vuuIzUq52gbxvpiSuzIau%2BuO9FUUfTvvCjcoQ4MMltRnEOqF0pdD%2FwiBZWxoqGCn8r2VGKIUCHOoTyHK2g7y1bsJRRqNe3%2FlXv5GbNhWEWXxbsf1UITRF4kYcM4KiI%2FbeFIevNNq7P2EIg0bVL%2BfqCcyYV2rbDdExWSPjUPPGBRh9JTowTscW0Dqf%2BwLXGmPthgKKMJo1f1OSQ29hf1Mbdlmg5NFV1H7KoICA3mruIQ4vl4TTFhvuAlxxrdb1J55KMJoBatEPCv6mr3sJzK%2F9RQKDAx49Ji5ctSLwsxAxgyuiduOAeVtIG14zppPKtAka9lcMZz71IHyNoAcCpvIx6UfxGLleCim3ggUpe0dQhe7I86mWvQERZmCIocryAqPsdYOSQlVIjCgyMRbLSaXxi3GD4LEw4AipzCyyvS5a5ThMpJTGAYUuQljhiWL53R11FN5BxhQsK0UWbE747E7evGV2FaEAUWmDave0H4LQxg6nErl1IEBBRdmOzjkBPpdqFB%2BpUtUGb0tDKloZP44hQLthQoDwXYiXlowpMJIymExdARL8SViYzymhGEMFR%2FR3cOyNoRCpQcZFu1s6AsNhlQuSiJP%2B1Kk90dNRHW9BYyhwlszhNgdb05CjmGcKDb3DotAoYIYV9wWxjDSZcHNmN%2Fj0KpPm3R7dMjq7HlrSokvjIqjww3SEhb4XJDpg3CLvM9%2BPG%2FMHOcaOwzYRFScNe8QHJb9nOEDhvkGwV48eZC3BgfzWwSHZaXthKEVMvkMaQnKhKESzSCkJ37uQqlJ7RmCIcbr%2By5qUEjiIwQK3q4yZKHqYDxEUIo4U6%2BNahxKr0kEZwv8HC%2BDqo69UaI2ieBAujN2RNhOoPybQjBr9oNSKNXSoQ%2B2luCUQuk1iSCIg9oiZl24Vv8TtXLROaotAtO3%2F9ooWSFcjDnH6BQio2SZQSRz%2FpsPfsifQ2RY1tmNBM3oxQRCbRjkOZn%2FEACT2J%2B1vkZiGESyG1SZS%2FqJ1wTogE1hEFHNh9yNCbvvREwqCwwoawwoKw0oKw0oKw0oKw0oKw0oKw0oMFYqMFYqMFYqMBYq88Y%2FxB7wiOJRvWkAAAAASUVORK5CYII%3D" /></a>
#
# ![version](https://img.shields.io/badge/version-1.0.0-blue)
# [![License: MIT](https://img.shields.io/badge/License-MIT-red.svg)](https://opensource.org/licenses/MIT)
# [![Open Source Love](https://firstcontributions.github.io/open-source-badges/badges/open-source-v2/open-source.svg)](https://github.com/firstcontributions/open-source-badges)
#
# A Google Summer of Code 2021 [Project](https://summerofcode.withgoogle.com/projects/#5612096894533632).<br>
# This project aims to demonstrate quantum machine learning's potential, specifically Quantum Convolutional Neural Network (QCNN), in HEP events classification from particle image data. The <b>code used in the research is wrapped as an open-source package</b> to ease future research in this field.<br>
#
#   <a href="https://ml4sci.org/" target="_blank"><img alt="gsoc@ml4sci" height="200px" src="https://raw.githubusercontent.com/eraraya-ricardo/qcnn-hep/main/assets/gsoc%40ml4sci.jpeg" /></a>
#
# </div>

# %% [markdown]
# # Note:
#
# This is a tutorial/example on how to use the package. For more detail information about the package itself and about notions like data re-uploading PQC, quantum classifier, quantum convolution, etc., please refer to the [Docs](https://colab.research.google.com/drive/1ojCEutBoHu-L6Q3PyWSYI51MNIr3OF_k?usp=sharing).
#
# We limit the tutorial to just binary classification tasks. But this package can easily be used for multi-class classification.

# %% [markdown]
# For a more in-depth theoretical equation, design details of the data re-uploading circuit, and how to construct a multi-class classification circuit, it is highly recommended to read the [original paper](https://quantum-journal.org/papers/q-2020-02-06-226/). The paper is very well written (clear, concise, easy to understand).

# %% [markdown]
# # 0. Import the Packages

# %% [markdown]
# Check GPU availability

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sat Aug 28 15:01:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Check RAM availability

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# To enable a high-RAM runtime, select the Runtime > "Change runtime type"
# menu, and then select High-RAM in the Runtime shape dropdown. Then,
# re-execute this cell.

# %% [markdown]
# Mount Google Drive to Google Colab (not needed if you run the Notebook locally)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# CD to where you want to clone the repository, and clone it

# %%
# %cd '/content/drive/My Drive/Projects/GSoC 2021/tutorials'
# !git clone https://github.com/eraraya-ricardo/qcnn-hep.git

from IPython.display import clear_output
clear_output()

# %% [markdown]
# After cloning the repository, cd to the `qcnn-hep` folder.
# Then, install the dependencies in the `requirements.txt` file, you only need to do this once.
# Once you have all the requirements, run the `!python setup.py` after cd-ing to the `qcnn-hep` folder everytime you want to load the package.

# %%
# %cd '/content/drive/My Drive/Projects/GSoC 2021/tutorials/qcnn-hep'
# !python -m pip install -r requirements.txt
# !python setup.py

from IPython.display import clear_output
clear_output()

# %% [markdown]
# Now, let's import all the packages.<br>
# Note: the `main_dir` is the directory where the models will be saved.

# %%
main_dir = '/content/drive/My Drive/Projects/GSoC 2021/tutorials'

import os
import sys

# Append the path to the folder ../qcnn-hep so we can import the package
sys.path.append('/content/drive/My Drive/Projects/GSoC 2021/tutorials/qcnn-hep')

import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf

import cirq
from cirq.contrib.svg import SVGCircuit

from qcnn_drc.data_reuploading import ReUploadingPQC
from qcnn_drc.quantum_convolution import QConv2D_DRC

# %% [markdown]
# # 1. Load MNIST Dataset

# %% [markdown]
# For all examples, we will train the models to classify [MNIST](http://yann.lecun.com/exdb/mnist/) dataset. This dataset is open-source and relatively easy to obtain by everyone.

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scale it by 255 so the pixel's value is in [0, 1]
x_train_flatten = x_train/255.0
x_test_flatten = x_test/255.0

# Separate the dataset into classes
x_train_0 = x_train_flatten[y_train == 0]
x_train_1 = x_train_flatten[y_train == 1]
x_train_2 = x_train_flatten[y_train == 2]
x_train_3 = x_train_flatten[y_train == 3]
x_train_4 = x_train_flatten[y_train == 4]
x_train_5 = x_train_flatten[y_train == 5]
x_train_6 = x_train_flatten[y_train == 6]
x_train_7 = x_train_flatten[y_train == 7]
x_train_8 = x_train_flatten[y_train == 8]
x_train_9 = x_train_flatten[y_train == 9]

x_train_list = [x_train_0, x_train_1, x_train_2, x_train_3, x_train_4, x_train_5, x_train_6, x_train_7, x_train_8, x_train_9]

print(x_train_0.shape)
print(x_train_1.shape)
print(x_train_2.shape)
print(x_train_3.shape)
print(x_train_4.shape)
print(x_train_5.shape)
print(x_train_6.shape)
print(x_train_7.shape)
print(x_train_8.shape)
print(x_train_9.shape)

x_test_0 = x_test_flatten[y_test == 0]
x_test_1 = x_test_flatten[y_test == 1]
x_test_2 = x_test_flatten[y_test == 2]
x_test_3 = x_test_flatten[y_test == 3]
x_test_4 = x_test_flatten[y_test == 4]
x_test_5 = x_test_flatten[y_test == 5]
x_test_6 = x_test_flatten[y_test == 6]
x_test_7 = x_test_flatten[y_test == 7]
x_test_8 = x_test_flatten[y_test == 8]
x_test_9 = x_test_flatten[y_test == 9]

x_test_list = [x_test_0, x_test_1, x_test_2, x_test_3, x_test_4, x_test_5, x_test_6, x_test_7, x_test_8, x_test_9]

print(x_test_0.shape)
print(x_test_1.shape)
print(x_test_2.shape)
print(x_test_3.shape)
print(x_test_4.shape)
print(x_test_5.shape)
print(x_test_6.shape)
print(x_test_7.shape)
print(x_test_8.shape)
print(x_test_9.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (5923, 28, 28)
# (6742, 28, 28)
# (5958, 28, 28)
# (6131, 28, 28)
# (5842, 28, 28)
# (5421, 28, 28)
# (5918, 28, 28)
# (6265, 28, 28)
# (5851, 28, 28)
# (5949, 28, 28)
# (980, 28, 28)
# (1135, 28, 28)
# (1032, 28, 28)
# (1010, 28, 28)
# (982, 28, 28)
# (892, 28, 28)
# (958, 28, 28)
# (1028, 28, 28)
# (974, 28, 28)
# (1009, 28, 28)

# %%
# Choose 2 classes (2 numbers)
class_set = [0, 1]

training_sample_per_class = 200  # number of training samples per class
X_train = np.concatenate((x_train_list[class_set[0]][:training_sample_per_class, :], x_train_list[class_set[1]][:training_sample_per_class, :]), axis=0)
Y_train = np.zeros((X_train.shape[0],), dtype=int)
Y_train[training_sample_per_class:] += 1

print("Train Set Shape:", X_train.shape, Y_train.shape)

testing_sample_per_class = 100  # number of testing samples per class
X_test = np.concatenate((x_test_list[class_set[0]][:testing_sample_per_class, :], x_test_list[class_set[1]][:testing_sample_per_class, :]), axis=0)
Y_test = np.zeros((X_test.shape[0],), dtype=int)
Y_test[testing_sample_per_class:] += 1

print("Test Set Shape:", X_test.shape, Y_test.shape)
# Out:
# Train Set Shape: (400, 28, 28) (400,)
# Test Set Shape: (200, 28, 28) (200,)

# %%
# Examples from train set
plt.imshow(np.concatenate((X_train[0], X_train[-1]), axis=1), cmap='gray')

# %%
# Examples from test set
plt.imshow(np.concatenate((X_test[0], X_test[-1]), axis=1), cmap='gray')

# %% [markdown]
# # 2. Utils

# %% [markdown]
# ## 2.1 Learning Rate Scheduler

# %% [markdown]
# This is an example of [Learning Rate Scheduler](https://keras.io/api/callbacks/learning_rate_scheduler/) function for training a model with Keras API. It will be used later in an example of training a quantum model.

# %%
def lr_schedule(epoch, lr_init=1e-3):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
        lr_init (float32): initial learning rate, default: 1e-3
    """
    lr = lr_init
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_schedule)

lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

# %% [markdown]
# ## 2.2 Callbacks

# %% [markdown]
# This is a [custom Keras Callback class](https://keras.io/guides/writing_your_own_callbacks/) to save the quantum model and its metrics during the training. It will be used later in an example of training a quantum model.

# %%
# Callback for saving model's weights, optimizer's states, and evaluation metrics
class CustomCallback(tf.keras.callbacks.Callback):

    def __init__(self, checkpoint_dir):
        super(CustomCallback, self).__init__()
        self.checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
        self.checkpoint = tf.train.Checkpoint(optimizer=opt_adam,
                                 model=model)

        try:
            self.best_metric_list = list(np.loadtxt(checkpoint_dir + '/history_best_metric_list.txt'))
        except:
            # acc, val acc, auc, val auc
            self.best_metric_list = [0, 0, 0, 0]

        def load_history(name):
            try:
                data = np.loadtxt(checkpoint_dir + '/history_' + name + '.txt')
                return list(data)
                
            except:
                return []

        self.accuracy_list = load_history('accuracy')
        self.val_accuracy_list = load_history('val_accuracy')
        self.auc_list = load_history('auc')
        self.val_auc_list = load_history('val_auc')
        self.loss_list = load_history('loss')
        self.val_loss_list = load_history('val_loss')

    def on_epoch_end(self, epoch, logs=None):
        self.checkpoint.save(file_prefix = self.checkpoint_prefix)
        print("Saved custom checkpoint for epoch {}.".format(epoch+1))

        def save_list_to_txt(metric, metric_list, name):
            metric_list += [metric]
            np.savetxt(checkpoint_dir + '/history_' + name + '.txt', np.array(metric_list))
            return metric_list

        self.accuracy_list = save_list_to_txt(logs["accuracy"], self.accuracy_list, 'accuracy')
        self.val_accuracy_list = save_list_to_txt(logs["val_accuracy"], self.val_accuracy_list, 'val_accuracy')
        self.auc_list = save_list_to_txt(logs["auc"], self.auc_list, 'auc')
        self.val_auc_list = save_list_to_txt(logs["val_auc"], self.val_auc_list, 'val_auc')
        self.loss_list = save_list_to_txt(logs["loss"], self.loss_list, 'loss')
        self.val_loss_list = save_list_to_txt(logs["val_loss"], self.val_loss_list, 'val_loss')
        
        print_space = 0

        if logs["accuracy"] > self.best_metric_list[0]:
            self.best_metric_list[0] = logs["accuracy"]
        
        if logs["val_accuracy"] > self.best_metric_list[1]:
            self.best_metric_list[1] = logs["val_accuracy"]

        if logs["auc"] > self.best_metric_list[2]:
            self.best_metric_list[2] = logs["auc"]

        if logs["val_auc"] > self.best_metric_list[3]:
            self.best_metric_list[3] = logs["val_auc"]

        np.savetxt(checkpoint_dir + '/history_best_metric_list.txt', np.array(self.best_metric_list))
        print("Best acc, val acc, auc, val auc:", self.best_metric_list)
        print('')

# Callbacks for saving weights only
def checkpoint_save_weights_only(checkpoint_dir):
    return tf.keras.callbacks.ModelCheckpoint(checkpoint_dir + '/{epoch:02d}epoch.h5',
                                              monitor='val_loss', verbose=1, save_best_only=False,
                                              save_weights_only=True, mode='auto', save_freq='epoch')

# %% [markdown]
# # 3. Quantum Classifier

# %% [markdown]
# In this third section, we will show how to build a quantum classifier with data re-uploading PQC.

# %% [markdown]
# In classical fully-connected neural networks, to produce an output vector with more than one prediction value, we can simply put more than one fully-connected nodes at the output layer.
#
# With data re-uploading PQC, we can either use a single data re-uploading PQC with multiple qubits and measure each qubit with an observable, or we can use multiple data re-uploading PQCs and measure each PQC with an observable. These are not equivalent as entangling layers might be involved. There is no "absolutely right" design choice as it is case-by-case basis, similar to there is no "the best" neural nets architecture.

# %% [markdown]
# ## 3.1 Data Preprocessing

# %% [markdown]
# Since a quantum classifier with data re-uploading PQC is similar to the fully-connected layer of classical neural networks, the input vector must be 1D dataset. Since MNIST is an image dataset, we have to flatten the image into 1D vector. The total number of features will now be $28\times28 = 784$, this is too much for the current quantum computing simulator. Hence, we use PCA to reduce the dimension to just, let's say, $6$ features.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train.reshape(-1, 28*28))
X_train_scaled = scaler.transform(X_train.reshape(-1, 28*28))
X_test_scaled = scaler.transform(X_test.reshape(-1, 28*28))

n_pca = 6
pca = PCA(n_components=n_pca)
pca.fit(X_train_scaled)

X_train_transform = pca.transform(X_train_scaled)
X_test_transform = pca.transform(X_test_scaled)

print(X_train_transform.shape, Y_train.shape)
print(X_test_transform.shape, Y_test.shape)
# Out:
# (400, 6) (400,)
# (200, 6) (200,)

# %% [markdown]
# ## 3.2 Example 1: A classifier consists of only one Data Re-uploading PQC (can be either single or multi-qubit circuit)

# %% [markdown]
# ### 3.2.1 Single-Qubit Case (One Prediction Output / One Output Node)

# %% [markdown]
# #### Build the Model

# %% [markdown]
# Building the Keras model with data re-uploading PQC is just like building a usual Keras model. We pass the input tensor to the data re-uploading PQC layer and construct the Keras model with the input tensor as its input and the measurement of data re-uploading PQC as its output.

# %% [markdown]
# We use $|1⟩⟨1|$ observable because we want the PQC to give us a number between 0 and 1 (binary classifier). After the training, ideally, the model should map images of the first class to $|0⟩$ state and the second class to $|1⟩$ state.

# %%
n_qubits = 1

# Construct the observable
qubits = cirq.GridQubit.rect(1, n_qubits)
Z = cirq.PauliString(cirq.Z(qubits[-1]))
I = cirq.PauliString(cirq.I(qubits[-1]))
observables = [-0.5*Z + 0.5*I]  # equivalent to |1⟩⟨1|

# Initialize the PQC
PQC = ReUploadingPQC(n_qubits, 1, n_pca, use_entanglement=True, use_terminal_entanglement=True, observables=observables)

# Construct the model
input_tensor = tf.keras.Input(shape=(n_pca,), dtype=tf.dtypes.float32, name='input')
quantum_classifier = PQC(input_tensor)
model = tf.keras.Model(inputs=[input_tensor], outputs=quantum_classifier)

# Optimizer
opt_adam = tf.keras.optimizers.Adam(lr=0.1)

# Compile the model with MSE loss
model.compile(loss='mse',
              optimizer=opt_adam,
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

SVGCircuit(PQC.circuit)

# %%
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 6)]               0
# _________________________________________________________________
# re-uploading_PQC (ReUploadin (None, 1)                 12
# =================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the Model

# %% [markdown]
# The constructed model can then be trained with the usual Keras training API.

# %%
last_epoch = 0

# Train the model
H = model.fit(X_train_transform, Y_train, initial_epoch=last_epoch,
              batch_size=32,
              epochs=20,
              validation_data=(X_test_transform, Y_test),
              shuffle=True)

# Print and plot the best metrics obtained during the training
print("Best Train Accuracy:", max(H.history['accuracy']))
print("Best Val Accuracy:", max(H.history['val_accuracy']))
print("Best Train AUC:", max(H.history['auc']))
print("Best Val AUC", max(H.history['val_auc']))

plt.plot(H.history['accuracy'], label='Train Accuracy')
plt.plot(H.history['val_accuracy'], label='Val Accuracy')
plt.plot(H.history['auc'], label='Train AUC')
plt.plot(H.history['val_auc'], label='Val AUC')

plt.xlabel('Epoch')

plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 34ms/step - loss: 0.2580 - accuracy: 0.6215 - auc: 0.6569 - val_loss: 0.1709 - val_accuracy: 0.7750 - val_auc: 0.8523
# Epoch 2/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1725 - accuracy: 0.7459 - auc: 0.8726 - val_loss: 0.1489 - val_accuracy: 0.7900 - val_auc: 0.8946
# Epoch 3/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1203 - accuracy: 0.8397 - auc: 0.9383 - val_loss: 0.0261 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 4/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0337 - accuracy: 0.9616 - auc: 0.9983 - val_loss: 0.0527 - val_accuracy: 0.9400 - val_auc: 1.0000
# Epoch 5/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0377 - accuracy: 0.9555 - auc: 0.9943 - val_loss: 0.0260 - val_accuracy: 0.9800 - val_auc: 1.0000
# Epoch 6/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0242 - accuracy: 0.9845 - auc: 0.9991 - val_loss: 0.0382 - val_accuracy: 0.9550 - val_auc: 0.9985
# Epoch 7/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0263 - accuracy: 0.9780 - auc: 0.9997 - val_loss: 0.0228 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 8/20
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0193 - accuracy: 0.9859 - auc: 0.9985 - val_loss: 0.0217 - val_accuracy: 0.9900 - val_auc: 0.9999
# Epoch 9/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0192 - accuracy: 0.9814 - auc: 0.9997 - val_loss: 0.0268 - val_accuracy: 0.9850 - val_auc: 1.0000
# Epoch 10/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0254 - accuracy: 0.9765 - auc: 0.9987 - val_loss: 0.0274 - val_accuracy: 0.9800 - val_auc: 1.0000
# Epoch 11/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0257 - accuracy: 0.9734 - auc: 0.9995 - val_loss: 0.0212 - val_accuracy: 0.9950 - val_auc: 0.9998
# Epoch 12/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0190 - accuracy: 0.9877 - auc: 0.9998 - val_loss: 0.0199 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 13/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0178 - accuracy: 0.9893 - auc: 0.9997 - val_loss: 0.0189 - val_accuracy: 0.9850 - val_auc: 0.9999
# Epoch 14/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0215 - accuracy: 0.9771 - auc: 0.9988 - val_loss: 0.0314 - val_accuracy: 0.9850 - val_auc: 0.9997
# Epoch 15/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0419 - accuracy: 0.9713 - auc: 0.9894 - val_loss: 0.0353 - val_accuracy: 0.9800 - val_auc: 0.9998
# Epoch 16/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0265 - accuracy: 0.9821 - auc: 0.9990 - val_loss: 0.0239 - val_accuracy: 0.9800 - val_auc: 0.9999
# Epoch 17/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0209 - accuracy: 0.9920 - auc: 0.9995 - val_loss: 0.0202 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 18/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0219 - accuracy: 0.9867 - auc: 0.9996 - val_loss: 0.0184 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 19/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0220 - accuracy: 0.9831 - auc: 0.9995 - val_loss: 0.0206 - val_accuracy: 0.9850 - val_auc: 0.9998
# Epoch 20/20
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0237 - accuracy: 0.9801 - auc: 0.9997 - val_loss: 0.0267 - val_accuracy: 0.9900 - val_auc: 1.0000
# Best Train Accuracy: 0.9900000095367432
# Best Val Accuracy: 0.9950000047683716
# Best Train AUC: 0.9996500611305237
# Best Val AUC 1.0

# %% [markdown]
# ### 3.2.2 Multi-Qubit Case (One Prediction Output / One Output Node)

# %% [markdown]
# #### Build the Model

# %%
n_qubits = 2

# Construct the observable
qubits = cirq.GridQubit.rect(1, n_qubits)
Z = cirq.PauliString(cirq.Z(qubits[-1]))
I = cirq.PauliString(cirq.I(qubits[-1]))
observables = [-0.5*Z + 0.5*I]  # equivalent to |1⟩⟨1| on the second qubit

# Initialize the PQC
PQC = ReUploadingPQC(n_qubits, 2, n_pca, use_entanglement=True, use_terminal_entanglement=True, observables=observables)

# Construct the model
input_tensor = tf.keras.Input(shape=(n_pca,), dtype=tf.dtypes.float32, name='input')
quantum_classifier = PQC(input_tensor)
model = tf.keras.Model(inputs=[input_tensor], outputs=quantum_classifier)

# Optimizer
opt_adam = tf.keras.optimizers.Adam(lr=0.1)

# Compile the model with MSE loss
model.compile(loss='mse',
              optimizer=opt_adam,
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

SVGCircuit(PQC.circuit)

# %%
model.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 6)]               0
# _________________________________________________________________
# re-uploading_PQC (ReUploadin (None, 1)                 48
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the Model

# %%
last_epoch = 0

# Train the model
H = model.fit(X_train_transform, Y_train, initial_epoch=last_epoch,
              batch_size=32,
              epochs=20,
              validation_data=(X_test_transform, Y_test),
              shuffle=True)

# Print and plot the best metrics obtained during the training
print("Best Train Accuracy:", max(H.history['accuracy']))
print("Best Val Accuracy:", max(H.history['val_accuracy']))
print("Best Train AUC:", max(H.history['auc']))
print("Best Val AUC", max(H.history['val_auc']))

plt.plot(H.history['accuracy'], label='Train Accuracy')
plt.plot(H.history['val_accuracy'], label='Val Accuracy')
plt.plot(H.history['auc'], label='Train AUC')
plt.plot(H.history['val_auc'], label='Val AUC')

plt.xlabel('Epoch')

plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 55ms/step - loss: 0.2144 - accuracy: 0.6828 - auc: 0.7494 - val_loss: 0.1114 - val_accuracy: 0.8700 - val_auc: 0.9615
# Epoch 2/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1234 - accuracy: 0.8409 - auc: 0.9437 - val_loss: 0.1009 - val_accuracy: 0.8700 - val_auc: 0.9675
# Epoch 3/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1041 - accuracy: 0.8644 - auc: 0.9714 - val_loss: 0.0913 - val_accuracy: 0.8950 - val_auc: 0.9756
# Epoch 4/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.1186 - accuracy: 0.8601 - auc: 0.9539 - val_loss: 0.1111 - val_accuracy: 0.9100 - val_auc: 0.9702
# Epoch 5/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.1042 - accuracy: 0.8720 - auc: 0.9560 - val_loss: 0.0423 - val_accuracy: 0.9850 - val_auc: 0.9998
# Epoch 6/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0407 - accuracy: 0.9680 - auc: 0.9969 - val_loss: 0.0282 - val_accuracy: 0.9750 - val_auc: 1.0000
# Epoch 7/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0222 - accuracy: 0.9797 - auc: 0.9987 - val_loss: 0.0168 - val_accuracy: 1.0000 - val_auc: 1.0000
# Epoch 8/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0281 - accuracy: 0.9755 - auc: 0.9989 - val_loss: 0.0187 - val_accuracy: 0.9950 - val_auc: 1.0000
# Epoch 9/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0183 - accuracy: 0.9956 - auc: 0.9999 - val_loss: 0.0314 - val_accuracy: 0.9750 - val_auc: 1.0000
# Epoch 10/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0286 - accuracy: 0.9691 - auc: 0.9987 - val_loss: 0.0286 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 11/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0282 - accuracy: 0.9830 - auc: 0.9994 - val_loss: 0.0179 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 12/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0247 - accuracy: 0.9736 - auc: 0.9989 - val_loss: 0.0244 - val_accuracy: 0.9750 - val_auc: 0.9988
# Epoch 13/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0220 - accuracy: 0.9874 - auc: 0.9997 - val_loss: 0.0099 - val_accuracy: 0.9950 - val_auc: 1.0000
# Epoch 14/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0121 - accuracy: 0.9943 - auc: 0.9996 - val_loss: 0.0175 - val_accuracy: 0.9900 - val_auc: 0.9999
# Epoch 15/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0240 - accuracy: 0.9833 - auc: 0.9995 - val_loss: 0.0187 - val_accuracy: 0.9900 - val_auc: 1.0000
# Epoch 16/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0158 - accuracy: 0.9970 - auc: 0.9999 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_auc: 1.0000
# Epoch 17/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0138 - accuracy: 0.9888 - auc: 0.9975 - val_loss: 0.0185 - val_accuracy: 0.9900 - val_auc: 0.9986
# Epoch 18/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0214 - accuracy: 0.9856 - auc: 0.9994 - val_loss: 0.0133 - val_accuracy: 0.9950 - val_auc: 1.0000
# Epoch 19/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0225 - accuracy: 0.9778 - auc: 0.9983 - val_loss: 0.0247 - val_accuracy: 0.9900 - val_auc: 0.9989
# Epoch 20/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0173 - accuracy: 0.9946 - auc: 0.9998 - val_loss: 0.0358 - val_accuracy: 0.9750 - val_auc: 0.9977
# Best Train Accuracy: 0.9900000095367432
# Best Val Accuracy: 1.0
# Best Train AUC: 0.9996625185012817
# Best Val AUC 1.0

# %% [markdown]
# ### 3.2.3 Multi-Qubit Case (Two Prediction Outputs / Two Output Nodes)

# %% [markdown]
# For a binary classification task, we can also make the model to produce two prediction outputs, $[1, 0]$ output for the first class and $[0, 1]$ output for the second class.

# %% [markdown]
# For a quantum classifier with data re-uploading PQC, this can be realized by either:
#
# 1. Use a single data re-uploading PQC but measure it with two different observables, let's say, with $|0⟩⟨0|$ on one qubit and $|1⟩⟨1|$ on the other. The example directly below is the implementation of this method.
#
# 2. Use two data re-uploading PQC and measure each PQC with a single observable, let's say, measure the first PQC with $|0⟩⟨0|$ on one of its qubit and measure the second PQC with $|1⟩⟨1|$ on one of its qubit. See section **3.3.1** for the implementation.

# %% [markdown]
# #### Build the Model

# %%
n_qubits = 2

# Construct the observable
qubits = cirq.GridQubit.rect(1, n_qubits)
Z_0 = cirq.PauliString(cirq.Z(qubits[0]))
I_0 = cirq.PauliString(cirq.I(qubits[0]))
Z_1 = cirq.PauliString(cirq.Z(qubits[1]))
I_1 = cirq.PauliString(cirq.I(qubits[1]))
observables = [0.5*Z_0 + 0.5*I_0, -0.5*Z_1 + 0.5*I_1]  # equivalent to |0⟩⟨0|⊗|1⟩⟨1|, or, |0⟩⟨0| for the first qubit and |1⟩⟨1| for the second qubit

# Initialize the PQC
PQC = ReUploadingPQC(n_qubits, 2, n_pca, use_entanglement=True, use_terminal_entanglement=True, observables=observables)

# Construct the model
input_tensor = tf.keras.Input(shape=(n_pca,), dtype=tf.dtypes.float32, name='input')
quantum_classifier = PQC(input_tensor)
model = tf.keras.Model(inputs=[input_tensor], outputs=quantum_classifier)

# Optimizer
opt_adam = tf.keras.optimizers.Adam(lr=0.1)

# Compile the model with MSE loss
model.compile(loss='mse',
              optimizer=opt_adam,
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

SVGCircuit(PQC.circuit)

# %%
model.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 6)]               0
# _________________________________________________________________
# re-uploading_PQC (ReUploadin (None, 2)                 48
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the Model

# %%
last_epoch = 0

# Train the model
H = model.fit(X_train_transform, tf.keras.utils.to_categorical(Y_train), initial_epoch=last_epoch,
              batch_size=32,
              epochs=20,
              validation_data=(X_test_transform, tf.keras.utils.to_categorical(Y_test)),
              shuffle=True)

# Compile the model with MSE loss
print("Best Train Accuracy:", max(H.history['accuracy']))
print("Best Val Accuracy:", max(H.history['val_accuracy']))
print("Best Train AUC:", max(H.history['auc']))
print("Best Val AUC", max(H.history['val_auc']))

plt.plot(H.history['accuracy'], label='Train Accuracy')
plt.plot(H.history['val_accuracy'], label='Val Accuracy')
plt.plot(H.history['auc'], label='Train AUC')
plt.plot(H.history['val_auc'], label='Val AUC')

plt.xlabel('Epoch')

plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 56ms/step - loss: 0.2953 - accuracy: 0.5535 - auc: 0.5456 - val_loss: 0.1855 - val_accuracy: 0.8100 - val_auc: 0.8008
# Epoch 2/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.1740 - accuracy: 0.8009 - auc: 0.8198 - val_loss: 0.1013 - val_accuracy: 0.9150 - val_auc: 0.9388
# Epoch 3/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0857 - accuracy: 0.9264 - auc: 0.9625 - val_loss: 0.0875 - val_accuracy: 0.9650 - val_auc: 0.9513
# Epoch 4/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0621 - accuracy: 0.9586 - auc: 0.9804 - val_loss: 0.0425 - val_accuracy: 0.9700 - val_auc: 0.9950
# Epoch 5/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0494 - accuracy: 0.9654 - auc: 0.9850 - val_loss: 0.0506 - val_accuracy: 0.9700 - val_auc: 0.9890
# Epoch 6/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0458 - accuracy: 0.9672 - auc: 0.9888 - val_loss: 0.0294 - val_accuracy: 0.9950 - val_auc: 0.9994
# Epoch 7/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0309 - accuracy: 0.9880 - auc: 0.9967 - val_loss: 0.0350 - val_accuracy: 0.9850 - val_auc: 0.9981
# Epoch 8/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0288 - accuracy: 0.9711 - auc: 0.9969 - val_loss: 0.0188 - val_accuracy: 1.0000 - val_auc: 1.0000
# Epoch 9/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0252 - accuracy: 0.9938 - auc: 0.9971 - val_loss: 0.0287 - val_accuracy: 0.9900 - val_auc: 0.9991
# Epoch 10/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0211 - accuracy: 0.9892 - auc: 0.9988 - val_loss: 0.0458 - val_accuracy: 0.9900 - val_auc: 0.9965
# Epoch 11/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0398 - accuracy: 0.9817 - auc: 0.9915 - val_loss: 0.0288 - val_accuracy: 0.9950 - val_auc: 0.9996
# Epoch 12/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0296 - accuracy: 0.9940 - auc: 0.9975 - val_loss: 0.0306 - val_accuracy: 0.9800 - val_auc: 0.9971
# Epoch 13/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0275 - accuracy: 0.9780 - auc: 0.9973 - val_loss: 0.0382 - val_accuracy: 0.9750 - val_auc: 0.9904
# Epoch 14/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0390 - accuracy: 0.9782 - auc: 0.9917 - val_loss: 0.0329 - val_accuracy: 0.9900 - val_auc: 0.9976
# Epoch 15/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0243 - accuracy: 0.9921 - auc: 0.9981 - val_loss: 0.0229 - val_accuracy: 0.9900 - val_auc: 0.9994
# Epoch 16/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0277 - accuracy: 0.9885 - auc: 0.9979 - val_loss: 0.0248 - val_accuracy: 1.0000 - val_auc: 0.9998
# Epoch 17/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0284 - accuracy: 0.9917 - auc: 0.9982 - val_loss: 0.0263 - val_accuracy: 0.9900 - val_auc: 0.9979
# Epoch 18/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0299 - accuracy: 0.9808 - auc: 0.9980 - val_loss: 0.0221 - val_accuracy: 0.9950 - val_auc: 0.9997
# Epoch 19/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0291 - accuracy: 0.9810 - auc: 0.9967 - val_loss: 0.0232 - val_accuracy: 0.9900 - val_auc: 0.9990
# Epoch 20/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0218 - accuracy: 0.9894 - auc: 0.9980 - val_loss: 0.0152 - val_accuracy: 0.9950 - val_auc: 0.9999
# Best Train Accuracy: 0.9900000095367432
# Best Val Accuracy: 1.0
# Best Train AUC: 0.99857497215271
# Best Val AUC 0.9999500513076782

# %% [markdown]
# ## 3.3 Example 2: A classifier consists of more than one Data Re-uploading PQC (use more than one qubit since a PQC needs at least one qubit)

# %% [markdown]
# It doesn't really make sense to use more than one PQC to produce one prediction value as every PQC will at least produce a measurement result of an observable. So in this example, only a model with two prediction outputs will be shown.

# %% [markdown]
# ### 3.3.1 Two Prediction Values / Two Output Nodes

# %% [markdown]
# #### Build the Model

# %%
# Construct the observable
n_qubits = 1
qubits = cirq.GridQubit.rect(1, n_qubits)
Z = cirq.PauliString(cirq.Z(qubits[-1]))
I = cirq.PauliString(cirq.I(qubits[-1]))
# Two observables, one for each PQC
observables_0 = [0.5*Z + 0.5*I]   # equivalent to |0⟩⟨0|
observables_1 = [-0.5*Z + 0.5*I]  # equivalent to |1⟩⟨1|

input_tensor = tf.keras.Input(shape=(n_pca,), dtype=tf.dtypes.float32, name='input')

PQC_1 = ReUploadingPQC(1, 1, n_pca, use_entanglement=False, use_terminal_entanglement=False, observables=observables_0, name='PQC_1')(input_tensor)
PQC_2 = ReUploadingPQC(1, 1, n_pca, use_entanglement=False, use_terminal_entanglement=False, observables=observables_1, name='PQC_2')(input_tensor)

output = tf.keras.layers.Concatenate()([PQC_1, PQC_2])

model = tf.keras.Model(inputs=[input_tensor], outputs=output)

# Optimizer
opt_adam = tf.keras.optimizers.Adam(lr=0.1)

# Compile the model with MSE loss
model.compile(loss='MSE',
              optimizer=opt_adam,
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

# %%
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 6)]          0
# __________________________________________________________________________________________________
# PQC_1 (ReUploadingPQC)          (None, 1)            12          input[0][0]
# __________________________________________________________________________________________________
# PQC_2 (ReUploadingPQC)          (None, 1)            12          input[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 2)            0           PQC_1[0][0]
#                                                                  PQC_2[0][0]
# ==================================================================================================
# Total params: 24
# Trainable params: 24
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train the Model

# %%
last_epoch = 0

# Train the model
H = model.fit(X_train_transform, tf.keras.utils.to_categorical(Y_train), initial_epoch=last_epoch,
              batch_size=32,
              epochs=100,
              validation_data=(X_test_transform, tf.keras.utils.to_categorical(Y_test)),
              shuffle=True)

# Print and plot the best metrics obtained during the training
print("Best Train Accuracy:", max(H.history['accuracy']))
print("Best Val Accuracy:", max(H.history['val_accuracy']))
print("Best Train AUC:", max(H.history['auc']))
print("Best Val AUC", max(H.history['val_auc']))

plt.plot(H.history['accuracy'], label='Train Accuracy')
plt.plot(H.history['val_accuracy'], label='Val Accuracy')
plt.plot(H.history['auc'], label='Train AUC')
plt.plot(H.history['val_auc'], label='Val AUC')

plt.xlabel('Epoch')

plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 52ms/step - loss: 0.2758 - accuracy: 0.6442 - auc: 0.6152 - val_loss: 0.2102 - val_accuracy: 0.8300 - val_auc: 0.7716
# Epoch 2/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1805 - accuracy: 0.8093 - auc: 0.8105 - val_loss: 0.1146 - val_accuracy: 0.9200 - val_auc: 0.9155
# Epoch 3/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.1147 - accuracy: 0.9218 - auc: 0.9126 - val_loss: 0.1194 - val_accuracy: 0.9050 - val_auc: 0.8937
# Epoch 4/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1037 - accuracy: 0.9344 - auc: 0.9326 - val_loss: 0.1148 - val_accuracy: 0.9050 - val_auc: 0.9276
# Epoch 5/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0977 - accuracy: 0.9510 - auc: 0.9411 - val_loss: 0.1095 - val_accuracy: 0.9450 - val_auc: 0.9404
# Epoch 6/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0891 - accuracy: 0.9618 - auc: 0.9503 - val_loss: 0.1047 - val_accuracy: 0.9250 - val_auc: 0.9292
# Epoch 7/100
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1007 - accuracy: 0.9437 - auc: 0.9383 - val_loss: 0.1132 - val_accuracy: 0.9200 - val_auc: 0.9094
# Epoch 8/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.1212 - accuracy: 0.9361 - auc: 0.9098 - val_loss: 0.1073 - val_accuracy: 0.9100 - val_auc: 0.9224
# Epoch 9/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0900 - accuracy: 0.9659 - auc: 0.9560 - val_loss: 0.1300 - val_accuracy: 0.9000 - val_auc: 0.8941
# Epoch 10/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1145 - accuracy: 0.9287 - auc: 0.9210 - val_loss: 0.1011 - val_accuracy: 0.9300 - val_auc: 0.9229
# Epoch 11/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1028 - accuracy: 0.9396 - auc: 0.9323 - val_loss: 0.0927 - val_accuracy: 0.9550 - val_auc: 0.9427
# Epoch 12/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0952 - accuracy: 0.9633 - auc: 0.9402 - val_loss: 0.0885 - val_accuracy: 0.9700 - val_auc: 0.9587
# Epoch 13/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0954 - accuracy: 0.9652 - auc: 0.9381 - val_loss: 0.1015 - val_accuracy: 0.9450 - val_auc: 0.9202
# Epoch 14/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0952 - accuracy: 0.9582 - auc: 0.9415 - val_loss: 0.1036 - val_accuracy: 0.9300 - val_auc: 0.9240
# Epoch 15/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0940 - accuracy: 0.9721 - auc: 0.9417 - val_loss: 0.0879 - val_accuracy: 0.9600 - val_auc: 0.9562
# Epoch 16/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0990 - accuracy: 0.9591 - auc: 0.9403 - val_loss: 0.1071 - val_accuracy: 0.9300 - val_auc: 0.9179
# Epoch 17/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0899 - accuracy: 0.9713 - auc: 0.9495 - val_loss: 0.1169 - val_accuracy: 0.9250 - val_auc: 0.9053
# Epoch 18/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1097 - accuracy: 0.9378 - auc: 0.9179 - val_loss: 0.1199 - val_accuracy: 0.8950 - val_auc: 0.8880
# Epoch 19/100
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0988 - accuracy: 0.9573 - auc: 0.9330 - val_loss: 0.1067 - val_accuracy: 0.9600 - val_auc: 0.9166
# Epoch 20/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.1096 - accuracy: 0.9543 - auc: 0.9208 - val_loss: 0.1106 - val_accuracy: 0.9450 - val_auc: 0.9138
# Epoch 21/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.1051 - accuracy: 0.9509 - auc: 0.9229 - val_loss: 0.1067 - val_accuracy: 0.9750 - val_auc: 0.9286
# Epoch 22/100
# 13/13 [==============================] - 0s 26ms/step - loss: 0.1047 - accuracy: 0.9228 - auc: 0.9252 - val_loss: 0.0944 - val_accuracy: 0.9400 - val_auc: 0.9418
# Epoch 23/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0854 - accuracy: 0.9546 - auc: 0.9511 - val_loss: 0.1041 - val_accuracy: 0.9050 - val_auc: 0.9168
# Epoch 24/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0912 - accuracy: 0.9587 - auc: 0.9473 - val_loss: 0.1003 - val_accuracy: 0.9550 - val_auc: 0.9357
# Epoch 25/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0811 - accuracy: 0.9773 - auc: 0.9605 - val_loss: 0.0904 - val_accuracy: 0.9700 - val_auc: 0.9375
# Epoch 26/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0952 - accuracy: 0.9746 - auc: 0.9444 - val_loss: 0.0900 - val_accuracy: 0.9550 - val_auc: 0.9492
# Epoch 27/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0908 - accuracy: 0.9613 - auc: 0.9528 - val_loss: 0.0964 - val_accuracy: 0.9450 - val_auc: 0.9389
# Epoch 28/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0972 - accuracy: 0.9457 - auc: 0.9403 - val_loss: 0.0897 - val_accuracy: 0.9700 - val_auc: 0.9503
# Epoch 29/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0906 - accuracy: 0.9852 - auc: 0.9517 - val_loss: 0.0941 - val_accuracy: 0.9500 - val_auc: 0.9446
# Epoch 30/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0733 - accuracy: 0.9848 - auc: 0.9677 - val_loss: 0.1106 - val_accuracy: 0.9400 - val_auc: 0.9144
# Epoch 31/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.1042 - accuracy: 0.9594 - auc: 0.9329 - val_loss: 0.1070 - val_accuracy: 0.9450 - val_auc: 0.9290
# Epoch 32/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1099 - accuracy: 0.9486 - auc: 0.9288 - val_loss: 0.1093 - val_accuracy: 0.9050 - val_auc: 0.9049
# Epoch 33/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0917 - accuracy: 0.9534 - auc: 0.9537 - val_loss: 0.1169 - val_accuracy: 0.9400 - val_auc: 0.9350
# Epoch 34/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0940 - accuracy: 0.9643 - auc: 0.9516 - val_loss: 0.1129 - val_accuracy: 0.9400 - val_auc: 0.9257
# Epoch 35/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0888 - accuracy: 0.9526 - auc: 0.9606 - val_loss: 0.1021 - val_accuracy: 0.9500 - val_auc: 0.9252
# Epoch 36/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1101 - accuracy: 0.9381 - auc: 0.9165 - val_loss: 0.0925 - val_accuracy: 0.9350 - val_auc: 0.9407
# Epoch 37/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1012 - accuracy: 0.9470 - auc: 0.9347 - val_loss: 0.1068 - val_accuracy: 0.9150 - val_auc: 0.9200
# Epoch 38/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1072 - accuracy: 0.9424 - auc: 0.9350 - val_loss: 0.1398 - val_accuracy: 0.9050 - val_auc: 0.8754
# Epoch 39/100
# 13/13 [==============================] - 0s 25ms/step - loss: 0.1258 - accuracy: 0.9509 - auc: 0.9012 - val_loss: 0.1315 - val_accuracy: 0.9200 - val_auc: 0.8859
# Epoch 40/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0986 - accuracy: 0.9554 - auc: 0.9353 - val_loss: 0.0875 - val_accuracy: 0.9600 - val_auc: 0.9556
# Epoch 41/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1127 - accuracy: 0.9543 - auc: 0.9290 - val_loss: 0.1016 - val_accuracy: 0.9550 - val_auc: 0.9283
# Epoch 42/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.1085 - accuracy: 0.9346 - auc: 0.9210 - val_loss: 0.0863 - val_accuracy: 0.9550 - val_auc: 0.9523
# Epoch 43/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0855 - accuracy: 0.9600 - auc: 0.9610 - val_loss: 0.1027 - val_accuracy: 0.9450 - val_auc: 0.9267
# Epoch 44/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0648 - accuracy: 0.9705 - auc: 0.9745 - val_loss: 0.0320 - val_accuracy: 0.9900 - val_auc: 0.9997
# Epoch 45/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0249 - accuracy: 0.9921 - auc: 0.9988 - val_loss: 0.0355 - val_accuracy: 0.9900 - val_auc: 0.9985
# Epoch 46/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0262 - accuracy: 0.9848 - auc: 0.9974 - val_loss: 0.0209 - val_accuracy: 0.9850 - val_auc: 0.9994
# Epoch 47/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0205 - accuracy: 0.9893 - auc: 0.9986 - val_loss: 0.0271 - val_accuracy: 0.9900 - val_auc: 0.9991
# Epoch 48/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0212 - accuracy: 0.9845 - auc: 0.9977 - val_loss: 0.0239 - val_accuracy: 0.9900 - val_auc: 0.9999
# Epoch 49/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0191 - accuracy: 0.9807 - auc: 0.9993 - val_loss: 0.0221 - val_accuracy: 0.9900 - val_auc: 0.9994
# Epoch 50/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0232 - accuracy: 0.9865 - auc: 0.9971 - val_loss: 0.0211 - val_accuracy: 0.9900 - val_auc: 0.9992
# Epoch 51/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0203 - accuracy: 0.9800 - auc: 0.9985 - val_loss: 0.0197 - val_accuracy: 0.9850 - val_auc: 0.9995
# Epoch 52/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0225 - accuracy: 0.9853 - auc: 0.9987 - val_loss: 0.0251 - val_accuracy: 0.9850 - val_auc: 0.9979
# Epoch 53/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0242 - accuracy: 0.9837 - auc: 0.9972 - val_loss: 0.0216 - val_accuracy: 0.9900 - val_auc: 0.9992
# Epoch 54/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0222 - accuracy: 0.9751 - auc: 0.9976 - val_loss: 0.0197 - val_accuracy: 0.9900 - val_auc: 0.9993
# Epoch 55/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0198 - accuracy: 0.9767 - auc: 0.9987 - val_loss: 0.0180 - val_accuracy: 0.9900 - val_auc: 0.9997
# Epoch 56/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0148 - accuracy: 0.9854 - auc: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9850 - val_auc: 0.9995
# Epoch 57/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0171 - accuracy: 0.9889 - auc: 0.9992 - val_loss: 0.0199 - val_accuracy: 0.9950 - val_auc: 0.9998
# Epoch 58/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0248 - accuracy: 0.9813 - auc: 0.9937 - val_loss: 0.0215 - val_accuracy: 0.9950 - val_auc: 0.9998
# Epoch 59/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0178 - accuracy: 0.9928 - auc: 0.9989 - val_loss: 0.0194 - val_accuracy: 0.9950 - val_auc: 0.9995
# Epoch 60/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0231 - accuracy: 0.9821 - auc: 0.9979 - val_loss: 0.0236 - val_accuracy: 0.9900 - val_auc: 0.9993
# Epoch 61/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0211 - accuracy: 0.9811 - auc: 0.9983 - val_loss: 0.0204 - val_accuracy: 0.9850 - val_auc: 0.9993
# Epoch 62/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0251 - accuracy: 0.9797 - auc: 0.9985 - val_loss: 0.0225 - val_accuracy: 0.9900 - val_auc: 0.9996
# Epoch 63/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0223 - accuracy: 0.9844 - auc: 0.9982 - val_loss: 0.0228 - val_accuracy: 0.9950 - val_auc: 0.9996
# Epoch 64/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0340 - accuracy: 0.9783 - auc: 0.9932 - val_loss: 0.0277 - val_accuracy: 0.9800 - val_auc: 0.9986
# Epoch 65/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0260 - accuracy: 0.9859 - auc: 0.9961 - val_loss: 0.0214 - val_accuracy: 0.9900 - val_auc: 0.9995
# Epoch 66/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0228 - accuracy: 0.9811 - auc: 0.9988 - val_loss: 0.0309 - val_accuracy: 0.9800 - val_auc: 0.9974
# Epoch 67/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0302 - accuracy: 0.9785 - auc: 0.9958 - val_loss: 0.0265 - val_accuracy: 0.9900 - val_auc: 0.9994
# Epoch 68/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0211 - accuracy: 0.9805 - auc: 0.9987 - val_loss: 0.0195 - val_accuracy: 0.9850 - val_auc: 0.9995
# Epoch 69/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0273 - accuracy: 0.9875 - auc: 0.9982 - val_loss: 0.0256 - val_accuracy: 0.9900 - val_auc: 0.9995
# Epoch 70/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0274 - accuracy: 0.9902 - auc: 0.9958 - val_loss: 0.0258 - val_accuracy: 0.9900 - val_auc: 0.9998
# Epoch 71/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0249 - accuracy: 0.9868 - auc: 0.9936 - val_loss: 0.0267 - val_accuracy: 0.9850 - val_auc: 0.9988
# Epoch 72/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0202 - accuracy: 0.9923 - auc: 0.9983 - val_loss: 0.0223 - val_accuracy: 0.9900 - val_auc: 0.9997
# Epoch 73/100
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0208 - accuracy: 0.9869 - auc: 0.9988 - val_loss: 0.0198 - val_accuracy: 0.9900 - val_auc: 0.9997
# Epoch 74/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0232 - accuracy: 0.9838 - auc: 0.9923 - val_loss: 0.0250 - val_accuracy: 0.9850 - val_auc: 0.9991
# Epoch 75/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0255 - accuracy: 0.9816 - auc: 0.9968 - val_loss: 0.0216 - val_accuracy: 0.9900 - val_auc: 0.9993
# Epoch 76/100
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0209 - accuracy: 0.9895 - auc: 0.9984 - val_loss: 0.0195 - val_accuracy: 0.9900 - val_auc: 0.9998
# Epoch 77/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0181 - accuracy: 0.9927 - auc: 0.9987 - val_loss: 0.0187 - val_accuracy: 0.9900 - val_auc: 0.9997
# Epoch 78/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0193 - accuracy: 0.9828 - auc: 0.9986 - val_loss: 0.0262 - val_accuracy: 0.9800 - val_auc: 0.9984
# Epoch 79/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0190 - accuracy: 0.9940 - auc: 0.9991 - val_loss: 0.0195 - val_accuracy: 0.9850 - val_auc: 0.9993
# Epoch 80/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0186 - accuracy: 0.9981 - auc: 0.9996 - val_loss: 0.0225 - val_accuracy: 0.9900 - val_auc: 0.9996
# Epoch 81/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0193 - accuracy: 0.9857 - auc: 0.9988 - val_loss: 0.0174 - val_accuracy: 0.9850 - val_auc: 0.9996
# Epoch 82/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0284 - accuracy: 0.9829 - auc: 0.9943 - val_loss: 0.0200 - val_accuracy: 0.9900 - val_auc: 0.9994
# Epoch 83/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0188 - accuracy: 0.9820 - auc: 0.9990 - val_loss: 0.0216 - val_accuracy: 0.9900 - val_auc: 0.9996
# Epoch 84/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0178 - accuracy: 0.9880 - auc: 0.9991 - val_loss: 0.0200 - val_accuracy: 0.9900 - val_auc: 0.9998
# Epoch 85/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0178 - accuracy: 0.9883 - auc: 0.9995 - val_loss: 0.0259 - val_accuracy: 0.9850 - val_auc: 0.9990
# Epoch 86/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0193 - accuracy: 0.9880 - auc: 0.9992 - val_loss: 0.0203 - val_accuracy: 0.9900 - val_auc: 0.9997
# Epoch 87/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0163 - accuracy: 0.9862 - auc: 0.9994 - val_loss: 0.0214 - val_accuracy: 0.9800 - val_auc: 0.9988
# Epoch 88/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0234 - accuracy: 0.9734 - auc: 0.9957 - val_loss: 0.0235 - val_accuracy: 0.9900 - val_auc: 0.9983
# Epoch 89/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0257 - accuracy: 0.9796 - auc: 0.9970 - val_loss: 0.0261 - val_accuracy: 0.9950 - val_auc: 0.9996
# Epoch 90/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0280 - accuracy: 0.9841 - auc: 0.9956 - val_loss: 0.0750 - val_accuracy: 0.9600 - val_auc: 0.9744
# Epoch 91/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0375 - accuracy: 0.9670 - auc: 0.9912 - val_loss: 0.0242 - val_accuracy: 0.9800 - val_auc: 0.9979
# Epoch 92/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0309 - accuracy: 0.9751 - auc: 0.9958 - val_loss: 0.0214 - val_accuracy: 0.9900 - val_auc: 0.9993
# Epoch 93/100
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0245 - accuracy: 0.9697 - auc: 0.9967 - val_loss: 0.0314 - val_accuracy: 0.9900 - val_auc: 0.9996
# Epoch 94/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0242 - accuracy: 0.9785 - auc: 0.9982 - val_loss: 0.0204 - val_accuracy: 0.9850 - val_auc: 0.9996
# Epoch 95/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0176 - accuracy: 0.9901 - auc: 0.9990 - val_loss: 0.0230 - val_accuracy: 0.9900 - val_auc: 0.9996
# Epoch 96/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0210 - accuracy: 0.9934 - auc: 0.9989 - val_loss: 0.0261 - val_accuracy: 0.9900 - val_auc: 0.9992
# Epoch 97/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0219 - accuracy: 0.9817 - auc: 0.9987 - val_loss: 0.0274 - val_accuracy: 0.9950 - val_auc: 0.9999
# Epoch 98/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0211 - accuracy: 0.9824 - auc: 0.9990 - val_loss: 0.0196 - val_accuracy: 0.9950 - val_auc: 0.9998
# Epoch 99/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0216 - accuracy: 0.9814 - auc: 0.9985 - val_loss: 0.0231 - val_accuracy: 0.9850 - val_auc: 0.9987
# Epoch 100/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0196 - accuracy: 0.9835 - auc: 0.9988 - val_loss: 0.0271 - val_accuracy: 0.9800 - val_auc: 0.9992
# Best Train Accuracy: 0.9925000071525574
# Best Val Accuracy: 0.9950000047683716
# Best Train AUC: 0.9991437792778015
# Best Val AUC 0.999862551689148

# %% [markdown]
# # 4. Hybrid Quantum-Classical QCNN

# %% [markdown]
# In this fourth section, we will show how to build a QCNN model with quantum convolution followed by classical fully-connected layer.

# %% [markdown]
# Since the quantum convolution layer (`QConv2D_DRC`) can take image data with multiple channels as its input, there is no need to flatten the image and reduce its dimension. Hence, for QCNN example, we will use the full size MNIST images.

# %% [markdown]
# ## Build the Model

# %% [markdown]
# Using the `QConv2D_DRC` layer is similar to using the [`Conv2D` layer](https://keras.io/api/layers/convolution_layers/convolution2d/) from Keras. We just need to pass the output tensor of the previous layer to it, and pass its output tensor to the next layer.
#
# A small difference is that we need to use the method `call()` for the `QConv2D_DRC` layer to work.

# %% [markdown]
# Let's build a model with two quantum convolution layers, a max pooling layer, followed by a classical fully-connected layer.

# %%
# Full size MNIST images as input with shape (28, 28, 1)
input_tensor = tf.keras.Input(shape=(28, 28, 1), dtype=tf.dtypes.float32, name='input')

drc_settings = {
    "n_qubits": [1],
    "n_layers": [1],
    "use_ent": [True],
    "use_terminal_ent": [True]
}

# Two quantum convolution layers
qconv_1 = QConv2D_DRC(1, (3,3), (2,2), drc_settings, 1, padding="valid").call(input_tensor)
qconv_2 = QConv2D_DRC(1, (3,3), (2,2), drc_settings, 2, padding="valid").call(qconv_1)

# A max pooling layer
pool = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding="valid")(qconv_2)

# Flatten the tensor
flat = tf.keras.layers.Flatten()(pool)

# A classical fully-connected layer
classical_dense = tf.keras.layers.Dense(2, activation='softmax')(flat)

model = tf.keras.Model(inputs=[input_tensor], outputs=classical_dense)

# %%
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# tf.compat.v1.pad_8 (TFOpLambda) (None, 29, 29, 1)    0           input[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_988 (S (None, 29, 29)       0           tf.compat.v1.pad_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_989 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_990 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_991 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_992 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_993 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_994 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_995 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_996 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_997 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_998 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_999 (S (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1000 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1001 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1002 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1003 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1004 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1005 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1006 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1007 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1008 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1009 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1010 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1011 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1012 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1013 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1014 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1015 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1016 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1017 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1018 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1019 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1020 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1021 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1022 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1023 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1024 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1025 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1026 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1027 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1028 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1029 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1030 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1031 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1032 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1033 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1034 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1035 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1036 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1037 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1038 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1039 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1040 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1041 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1042 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1043 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1044 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1045 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1046 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1047 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1048 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1049 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1050 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1051 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1052 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1053 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1054 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1055 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1056 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1057 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1058 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1059 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1060 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1061 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1062 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1063 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1064 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1065 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1066 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1067 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1068 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1069 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1070 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1071 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1072 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1073 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1074 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1075 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1076 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1077 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1078 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1079 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1080 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1081 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1082 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1083 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1084 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1085 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1086 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1087 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1088 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1089 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1090 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1091 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1092 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1093 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1094 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1095 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1096 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1097 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1098 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1099 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1100 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1101 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1102 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1103 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1104 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1105 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1106 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1107 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1108 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1109 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1110 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1111 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1112 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1113 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1114 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1115 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1116 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1117 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1118 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1119 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1120 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1121 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1122 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1123 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1124 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1125 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1126 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1127 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1128 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1129 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1130 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1131 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1132 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1133 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1134 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1135 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1136 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1137 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1138 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1139 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1140 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1141 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1142 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1143 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1144 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1145 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1146 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1147 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1148 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1149 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1150 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1151 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1152 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1153 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1154 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1155 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1156 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1157 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1158 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1159 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1160 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1161 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1162 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1163 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1164 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1165 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1166 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1167 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1168 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1169 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1170 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1171 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1172 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1173 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1174 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1175 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1176 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1177 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1178 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1179 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1180 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1181 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1182 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1183 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1184 ( (None, 3, 3)         0           tf.__operators__.getitem_988[0][0
# __________________________________________________________________________________________________
# QConv_Operation_1_1_1 (ReUpload (None, 1)            18          tf.__operators__.getitem_989[0][0
#                                                                  tf.__operators__.getitem_990[0][0
#                                                                  tf.__operators__.getitem_991[0][0
#                                                                  tf.__operators__.getitem_992[0][0
#                                                                  tf.__operators__.getitem_993[0][0
#                                                                  tf.__operators__.getitem_994[0][0
#                                                                  tf.__operators__.getitem_995[0][0
#                                                                  tf.__operators__.getitem_996[0][0
#                                                                  tf.__operators__.getitem_997[0][0
#                                                                  tf.__operators__.getitem_998[0][0
#                                                                  tf.__operators__.getitem_999[0][0
#                                                                  tf.__operators__.getitem_1000[0][
#                                                                  tf.__operators__.getitem_1001[0][
#                                                                  tf.__operators__.getitem_1002[0][
#                                                                  tf.__operators__.getitem_1003[0][
#                                                                  tf.__operators__.getitem_1004[0][
#                                                                  tf.__operators__.getitem_1005[0][
#                                                                  tf.__operators__.getitem_1006[0][
#                                                                  tf.__operators__.getitem_1007[0][
#                                                                  tf.__operators__.getitem_1008[0][
#                                                                  tf.__operators__.getitem_1009[0][
#                                                                  tf.__operators__.getitem_1010[0][
#                                                                  tf.__operators__.getitem_1011[0][
#                                                                  tf.__operators__.getitem_1012[0][
#                                                                  tf.__operators__.getitem_1013[0][
#                                                                  tf.__operators__.getitem_1014[0][
#                                                                  tf.__operators__.getitem_1015[0][
#                                                                  tf.__operators__.getitem_1016[0][
#                                                                  tf.__operators__.getitem_1017[0][
#                                                                  tf.__operators__.getitem_1018[0][
#                                                                  tf.__operators__.getitem_1019[0][
#                                                                  tf.__operators__.getitem_1020[0][
#                                                                  tf.__operators__.getitem_1021[0][
#                                                                  tf.__operators__.getitem_1022[0][
#                                                                  tf.__operators__.getitem_1023[0][
#                                                                  tf.__operators__.getitem_1024[0][
#                                                                  tf.__operators__.getitem_1025[0][
#                                                                  tf.__operators__.getitem_1026[0][
#                                                                  tf.__operators__.getitem_1027[0][
#                                                                  tf.__operators__.getitem_1028[0][
#                                                                  tf.__operators__.getitem_1029[0][
#                                                                  tf.__operators__.getitem_1030[0][
#                                                                  tf.__operators__.getitem_1031[0][
#                                                                  tf.__operators__.getitem_1032[0][
#                                                                  tf.__operators__.getitem_1033[0][
#                                                                  tf.__operators__.getitem_1034[0][
#                                                                  tf.__operators__.getitem_1035[0][
#                                                                  tf.__operators__.getitem_1036[0][
#                                                                  tf.__operators__.getitem_1037[0][
#                                                                  tf.__operators__.getitem_1038[0][
#                                                                  tf.__operators__.getitem_1039[0][
#                                                                  tf.__operators__.getitem_1040[0][
#                                                                  tf.__operators__.getitem_1041[0][
#                                                                  tf.__operators__.getitem_1042[0][
#                                                                  tf.__operators__.getitem_1043[0][
#                                                                  tf.__operators__.getitem_1044[0][
#                                                                  tf.__operators__.getitem_1045[0][
#                                                                  tf.__operators__.getitem_1046[0][
#                                                                  tf.__operators__.getitem_1047[0][
#                                                                  tf.__operators__.getitem_1048[0][
#                                                                  tf.__operators__.getitem_1049[0][
#                                                                  tf.__operators__.getitem_1050[0][
#                                                                  tf.__operators__.getitem_1051[0][
#                                                                  tf.__operators__.getitem_1052[0][
#                                                                  tf.__operators__.getitem_1053[0][
#                                                                  tf.__operators__.getitem_1054[0][
#                                                                  tf.__operators__.getitem_1055[0][
#                                                                  tf.__operators__.getitem_1056[0][
#                                                                  tf.__operators__.getitem_1057[0][
#                                                                  tf.__operators__.getitem_1058[0][
#                                                                  tf.__operators__.getitem_1059[0][
#                                                                  tf.__operators__.getitem_1060[0][
#                                                                  tf.__operators__.getitem_1061[0][
#                                                                  tf.__operators__.getitem_1062[0][
#                                                                  tf.__operators__.getitem_1063[0][
#                                                                  tf.__operators__.getitem_1064[0][
#                                                                  tf.__operators__.getitem_1065[0][
#                                                                  tf.__operators__.getitem_1066[0][
#                                                                  tf.__operators__.getitem_1067[0][
#                                                                  tf.__operators__.getitem_1068[0][
#                                                                  tf.__operators__.getitem_1069[0][
#                                                                  tf.__operators__.getitem_1070[0][
#                                                                  tf.__operators__.getitem_1071[0][
# ...
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1210 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1211 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1212 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1213 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1214 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1215 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1216 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1217 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1218 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1219 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1220 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1221 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1222 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1223 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1224 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1225 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1226 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1227 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1228 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1229 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1230 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1231 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1232 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1233 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1234 ( (None, 3, 3)         0           tf.__operators__.getitem_1185[0][
# __________________________________________________________________________________________________
# QConv_Operation_2_1_1 (ReUpload (None, 1)            18          tf.__operators__.getitem_1186[0][
#                                                                  tf.__operators__.getitem_1187[0][
#                                                                  tf.__operators__.getitem_1188[0][
#                                                                  tf.__operators__.getitem_1189[0][
#                                                                  tf.__operators__.getitem_1190[0][
#                                                                  tf.__operators__.getitem_1191[0][
#                                                                  tf.__operators__.getitem_1192[0][
#                                                                  tf.__operators__.getitem_1193[0][
#                                                                  tf.__operators__.getitem_1194[0][
#                                                                  tf.__operators__.getitem_1195[0][
#                                                                  tf.__operators__.getitem_1196[0][
#                                                                  tf.__operators__.getitem_1197[0][
#                                                                  tf.__operators__.getitem_1198[0][
#                                                                  tf.__operators__.getitem_1199[0][
#                                                                  tf.__operators__.getitem_1200[0][
#                                                                  tf.__operators__.getitem_1201[0][
#                                                                  tf.__operators__.getitem_1202[0][
#                                                                  tf.__operators__.getitem_1203[0][
#                                                                  tf.__operators__.getitem_1204[0][
#                                                                  tf.__operators__.getitem_1205[0][
#                                                                  tf.__operators__.getitem_1206[0][
#                                                                  tf.__operators__.getitem_1207[0][
#                                                                  tf.__operators__.getitem_1208[0][
#                                                                  tf.__operators__.getitem_1209[0][
#                                                                  tf.__operators__.getitem_1210[0][
#                                                                  tf.__operators__.getitem_1211[0][
#                                                                  tf.__operators__.getitem_1212[0][
#                                                                  tf.__operators__.getitem_1213[0][
#                                                                  tf.__operators__.getitem_1214[0][
#                                                                  tf.__operators__.getitem_1215[0][
#                                                                  tf.__operators__.getitem_1216[0][
#                                                                  tf.__operators__.getitem_1217[0][
#                                                                  tf.__operators__.getitem_1218[0][
#                                                                  tf.__operators__.getitem_1219[0][
#                                                                  tf.__operators__.getitem_1220[0][
#                                                                  tf.__operators__.getitem_1221[0][
#                                                                  tf.__operators__.getitem_1222[0][
#                                                                  tf.__operators__.getitem_1223[0][
#                                                                  tf.__operators__.getitem_1224[0][
#                                                                  tf.__operators__.getitem_1225[0][
#                                                                  tf.__operators__.getitem_1226[0][
#                                                                  tf.__operators__.getitem_1227[0][
#                                                                  tf.__operators__.getitem_1228[0][
#                                                                  tf.__operators__.getitem_1229[0][
#                                                                  tf.__operators__.getitem_1230[0][
#                                                                  tf.__operators__.getitem_1231[0][
#                                                                  tf.__operators__.getitem_1232[0][
#                                                                  tf.__operators__.getitem_1233[0][
#                                                                  tf.__operators__.getitem_1234[0][
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 49)           0           QConv_Operation_2_1_1[0][0]
#                                                                  QConv_Operation_2_1_1[1][0]
#                                                                  QConv_Operation_2_1_1[2][0]
#                                                                  QConv_Operation_2_1_1[3][0]
#                                                                  QConv_Operation_2_1_1[4][0]
#                                                                  QConv_Operation_2_1_1[5][0]
#                                                                  QConv_Operation_2_1_1[6][0]
#                                                                  QConv_Operation_2_1_1[7][0]
#                                                                  QConv_Operation_2_1_1[8][0]
#                                                                  QConv_Operation_2_1_1[9][0]
#                                                                  QConv_Operation_2_1_1[10][0]
#                                                                  QConv_Operation_2_1_1[11][0]
#                                                                  QConv_Operation_2_1_1[12][0]
#                                                                  QConv_Operation_2_1_1[13][0]
#                                                                  QConv_Operation_2_1_1[14][0]
#                                                                  QConv_Operation_2_1_1[15][0]
#                                                                  QConv_Operation_2_1_1[16][0]
#                                                                  QConv_Operation_2_1_1[17][0]
#                                                                  QConv_Operation_2_1_1[18][0]
#                                                                  QConv_Operation_2_1_1[19][0]
#                                                                  QConv_Operation_2_1_1[20][0]
#                                                                  QConv_Operation_2_1_1[21][0]
#                                                                  QConv_Operation_2_1_1[22][0]
#                                                                  QConv_Operation_2_1_1[23][0]
#                                                                  QConv_Operation_2_1_1[24][0]
#                                                                  QConv_Operation_2_1_1[25][0]
#                                                                  QConv_Operation_2_1_1[26][0]
#                                                                  QConv_Operation_2_1_1[27][0]
#                                                                  QConv_Operation_2_1_1[28][0]
#                                                                  QConv_Operation_2_1_1[29][0]
#                                                                  QConv_Operation_2_1_1[30][0]
#                                                                  QConv_Operation_2_1_1[31][0]
#                                                                  QConv_Operation_2_1_1[32][0]
#                                                                  QConv_Operation_2_1_1[33][0]
#                                                                  QConv_Operation_2_1_1[34][0]
#                                                                  QConv_Operation_2_1_1[35][0]
#                                                                  QConv_Operation_2_1_1[36][0]
#                                                                  QConv_Operation_2_1_1[37][0]
#                                                                  QConv_Operation_2_1_1[38][0]
#                                                                  QConv_Operation_2_1_1[39][0]
#                                                                  QConv_Operation_2_1_1[40][0]
#                                                                  QConv_Operation_2_1_1[41][0]
#                                                                  QConv_Operation_2_1_1[42][0]
#                                                                  QConv_Operation_2_1_1[43][0]
#                                                                  QConv_Operation_2_1_1[44][0]
#                                                                  QConv_Operation_2_1_1[45][0]
#                                                                  QConv_Operation_2_1_1[46][0]
#                                                                  QConv_Operation_2_1_1[47][0]
#                                                                  QConv_Operation_2_1_1[48][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 7, 7, 1)      0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 3, 3, 1)      0           reshape_9[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 9)            0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 2)            20          flatten_4[0][0]
# ==================================================================================================
# Total params: 56
# Trainable params: 56
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Since this model is more complicated, it may takes longer and harder to train. Therefore, for this example, we will use the Learning Rate Scheduler to change the learning rate during the training. We will also save both the model's state and the optimizer's state so we can continue the training from the save files later if needed.

# %% [markdown]
# Also, instead of MSE, let's try different loss function. This time, we will try the cross-entropy loss.

# %%
# Training parameters
BATCH_SIZE = 32
EPOCHS = 100

# Print parameters for sanity check
print("Batch size, epochs:", BATCH_SIZE, EPOCHS)

# Optimizer with learning rate scheduler
opt_adam = tf.keras.optimizers.Adam(lr=lr_schedule(0, lr_init=0.01))

# Compile the model with cross-entropy loss
model.compile(loss='categorical_crossentropy',
              optimizer=opt_adam,
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
# Out:
# Batch size, epochs: 32 100
# Learning rate:  0.01

# %%
# The directory on where we want to save the model
checkpoint_dir = main_dir + '/Hybrid'

# Initialize callbacks
# Let's use both callbacks that we have prepared just in case
cp_1 = CustomCallback(checkpoint_dir)
cp_2 = checkpoint_save_weights_only(checkpoint_dir)

# A list of callbacks to be passed on the Keras' model training API
callback_list = [cp_1, cp_2, lr_reducer, lr_scheduler]

# %% [markdown]
# ## Train the Model

# %%
last_epoch = 0

# Train the model
H = model.fit(X_train, tf.keras.utils.to_categorical(Y_train), initial_epoch=last_epoch,
              batch_size=BATCH_SIZE,
              epochs=EPOCHS,
              validation_data=(X_test, tf.keras.utils.to_categorical(Y_test)),
              shuffle=True,
              callbacks=callback_list)

# Print and plot the best metrics obtained during the training
print("Best Train Accuracy:", max(H.history['accuracy']))
print("Best Val Accuracy:", max(H.history['val_accuracy']))
print("Best Train AUC:", max(H.history['auc']))
print("Best Val AUC", max(H.history['val_auc']))

plt.plot(H.history['accuracy'], label='Train Accuracy')
plt.plot(H.history['val_accuracy'], label='Val Accuracy')
plt.plot(H.history['auc'], label='Train AUC')
plt.plot(H.history['val_auc'], label='Val AUC')

plt.xlabel('Epoch')

plt.legend()
plt.show()
# Out:
# Epoch 1/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 136s 4s/step - loss: 0.7437 - accuracy: 0.5028 - auc: 0.4980 - val_loss: 0.7027 - val_accuracy: 0.5000 - val_auc: 0.5055
# Saved custom checkpoint for epoch 1.
# Best acc, val acc, auc, val auc: [0.5099999904632568, 0.5, 0.5544000267982483, 0.5055000185966492]
#
#
# Epoch 00001: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/01epoch.h5
# Epoch 2/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 28s 2s/step - loss: 0.6941 - accuracy: 0.4978 - auc: 0.6106 - val_loss: 0.6943 - val_accuracy: 0.3950 - val_auc: 0.4662
# Saved custom checkpoint for epoch 2.
# Best acc, val acc, auc, val auc: [0.5099999904632568, 0.5, 0.6250249743461609, 0.5055000185966492]
#
#
# Epoch 00002: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/02epoch.h5
# Epoch 3/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.6382 - accuracy: 0.5011 - auc: 0.6613 - val_loss: 0.6278 - val_accuracy: 0.6350 - val_auc: 0.7031
# Saved custom checkpoint for epoch 3.
# Best acc, val acc, auc, val auc: [0.5274999737739563, 0.6349999904632568, 0.683440625667572, 0.7030624747276306]
#
#
# Epoch 00003: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/03epoch.h5
# Epoch 4/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.4553 - accuracy: 0.8330 - auc: 0.9129 - val_loss: 0.3899 - val_accuracy: 0.8500 - val_auc: 0.9200
# Saved custom checkpoint for epoch 4.
# Best acc, val acc, auc, val auc: [0.8650000095367432, 0.8500000238418579, 0.9396187663078308, 0.9200374484062195]
#
#
# Epoch 00004: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/04epoch.h5
# Epoch 5/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.2412 - accuracy: 0.9308 - auc: 0.9751 - val_loss: 0.2249 - val_accuracy: 0.9000 - val_auc: 0.9742
# Saved custom checkpoint for epoch 5.
# Best acc, val acc, auc, val auc: [0.9350000023841858, 0.8999999761581421, 0.9801905751228333, 0.9741500616073608]
#
#
# Epoch 00005: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/05epoch.h5
# Epoch 6/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.1462 - accuracy: 0.9529 - auc: 0.9903 - val_loss: 0.1309 - val_accuracy: 0.9800 - val_auc: 0.9929
# Saved custom checkpoint for epoch 6.
# Best acc, val acc, auc, val auc: [0.9599999785423279, 0.9800000190734863, 0.9914374351501465, 0.9929499626159668]
#
#
# Epoch 00006: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/06epoch.h5
# Epoch 7/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.1111 - accuracy: 0.9736 - auc: 0.9953 - val_loss: 0.1113 - val_accuracy: 0.9850 - val_auc: 0.9925
# Saved custom checkpoint for epoch 7.
# Best acc, val acc, auc, val auc: [0.9775000214576721, 0.9850000143051147, 0.9939124584197998, 0.9929499626159668]
#
#
# Epoch 00007: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/07epoch.h5
# Epoch 8/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0909 - accuracy: 0.9704 - auc: 0.9966 - val_loss: 0.0794 - val_accuracy: 0.9900 - val_auc: 0.9953
# Saved custom checkpoint for epoch 8.
# Best acc, val acc, auc, val auc: [0.9775000214576721, 0.9900000095367432, 0.9948062300682068, 0.9952749609947205]
#
#
# Epoch 00008: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/08epoch.h5
# Epoch 9/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0734 - accuracy: 0.9851 - auc: 0.9974 - val_loss: 0.0765 - val_accuracy: 0.9900 - val_auc: 0.9950
# Saved custom checkpoint for epoch 9.
# Best acc, val acc, auc, val auc: [0.9825000166893005, 0.9900000095367432, 0.9962812662124634, 0.9952749609947205]
#
#
# Epoch 00009: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/09epoch.h5
# Epoch 10/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0999 - accuracy: 0.9664 - auc: 0.9935 - val_loss: 0.0630 - val_accuracy: 0.9900 - val_auc: 0.9967
# Saved custom checkpoint for epoch 10.
# Best acc, val acc, auc, val auc: [0.9825000166893005, 0.9900000095367432, 0.9969374537467957, 0.9967000484466553]
#
#
# Epoch 00010: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/10epoch.h5
# Epoch 11/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0553 - accuracy: 0.9885 - auc: 0.9985 - val_loss: 0.0640 - val_accuracy: 0.9900 - val_auc: 0.9960
# Saved custom checkpoint for epoch 11.
# Best acc, val acc, auc, val auc: [0.9850000143051147, 0.9900000095367432, 0.997112512588501, 0.9967000484466553]
#
#
# Epoch 00011: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/11epoch.h5
# Epoch 12/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0635 - accuracy: 0.9839 - auc: 0.9969 - val_loss: 0.0504 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 12.
# Best acc, val acc, auc, val auc: [0.9850000143051147, 0.9900000095367432, 0.9974875450134277, 0.9981000423431396]
#
#
# Epoch 00012: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/12epoch.h5
# Epoch 13/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0536 - accuracy: 0.9890 - auc: 0.9977 - val_loss: 0.0562 - val_accuracy: 0.9900 - val_auc: 0.9967
# Saved custom checkpoint for epoch 13.
# Best acc, val acc, auc, val auc: [0.9850000143051147, 0.9900000095367432, 0.9979375004768372, 0.9981000423431396]
#
#
# Epoch 00013: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/13epoch.h5
# Epoch 14/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 30s 2s/step - loss: 0.0707 - accuracy: 0.9810 - auc: 0.9950 - val_loss: 0.0420 - val_accuracy: 0.9900 - val_auc: 0.9992
# Saved custom checkpoint for epoch 14.
# Best acc, val acc, auc, val auc: [0.9850000143051147, 0.9900000095367432, 0.9979875683784485, 0.9992499947547913]
#
#
# Epoch 00014: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/14epoch.h5
# Epoch 15/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0601 - accuracy: 0.9838 - auc: 0.9973 - val_loss: 0.0519 - val_accuracy: 0.9900 - val_auc: 0.9969
# Saved custom checkpoint for epoch 15.
# Best acc, val acc, auc, val auc: [0.987500011920929, 0.9900000095367432, 0.9984375238418579, 0.9992499947547913]
#
#
# Epoch 00015: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/15epoch.h5
# Epoch 16/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0444 - accuracy: 0.9856 - auc: 0.9988 - val_loss: 0.0419 - val_accuracy: 0.9900 - val_auc: 0.9987
# Saved custom checkpoint for epoch 16.
# Best acc, val acc, auc, val auc: [0.987500011920929, 0.9900000095367432, 0.9984375238418579, 0.9992499947547913]
#
#
# Epoch 00016: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/16epoch.h5
# Epoch 17/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0467 - accuracy: 0.9895 - auc: 0.9975 - val_loss: 0.0440 - val_accuracy: 0.9900 - val_auc: 0.9978
# Saved custom checkpoint for epoch 17.
# Best acc, val acc, auc, val auc: [0.987500011920929, 0.9900000095367432, 0.9985312223434448, 0.9992499947547913]
#
#
# Epoch 00017: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/17epoch.h5
# Epoch 18/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0433 - accuracy: 0.9861 - auc: 0.9990 - val_loss: 0.0386 - val_accuracy: 0.9900 - val_auc: 0.9992
# Saved custom checkpoint for epoch 18.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9986438751220703, 0.9992499947547913]
#
#
# Epoch 00018: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/18epoch.h5
# Epoch 19/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0351 - accuracy: 0.9935 - auc: 0.9991 - val_loss: 0.0378 - val_accuracy: 0.9900 - val_auc: 0.9991
# Saved custom checkpoint for epoch 19.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9989187717437744, 0.9992499947547913]
#
#
# Epoch 00019: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/19epoch.h5
# Epoch 20/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0372 - accuracy: 0.9875 - auc: 0.9994 - val_loss: 0.0448 - val_accuracy: 0.9900 - val_auc: 0.9976
# Saved custom checkpoint for epoch 20.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9991000890731812, 0.9992499947547913]
#
#
# Epoch 00020: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/20epoch.h5
# Epoch 21/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0350 - accuracy: 0.9895 - auc: 0.9997 - val_loss: 0.0389 - val_accuracy: 0.9900 - val_auc: 0.9985
# Saved custom checkpoint for epoch 21.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.999356210231781, 0.9992499947547913]
#
#
# Epoch 00021: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/21epoch.h5
# Epoch 22/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0338 - accuracy: 0.9907 - auc: 0.9995 - val_loss: 0.0402 - val_accuracy: 0.9900 - val_auc: 0.9982
# Saved custom checkpoint for epoch 22.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9994000196456909, 0.9992499947547913]
#
#
# Epoch 00022: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/22epoch.h5
# Epoch 23/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 30s 2s/step - loss: 0.0229 - accuracy: 0.9953 - auc: 0.9999 - val_loss: 0.0337 - val_accuracy: 0.9900 - val_auc: 0.9990
# Saved custom checkpoint for epoch 23.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9997249841690063, 0.9992499947547913]
#
#
# Epoch 00023: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/23epoch.h5
# Epoch 24/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0351 - accuracy: 0.9852 - auc: 0.9996 - val_loss: 0.0370 - val_accuracy: 0.9900 - val_auc: 0.9985
# Saved custom checkpoint for epoch 24.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9997249841690063, 0.9992499947547913]
#
#
# Epoch 00024: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/24epoch.h5
# Epoch 25/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0476 - accuracy: 0.9808 - auc: 0.9988 - val_loss: 0.0404 - val_accuracy: 0.9900 - val_auc: 0.9975
# Saved custom checkpoint for epoch 25.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9997749924659729, 0.9992499947547913]
#
#
# Epoch 00025: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/25epoch.h5
# Epoch 26/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0289 - accuracy: 0.9912 - auc: 0.9998 - val_loss: 0.0373 - val_accuracy: 0.9900 - val_auc: 0.9978
# Saved custom checkpoint for epoch 26.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9997749924659729, 0.9992499947547913]
#
#
# Epoch 00026: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/26epoch.h5
# Epoch 27/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0214 - accuracy: 0.9919 - auc: 0.9998 - val_loss: 0.0353 - val_accuracy: 0.9900 - val_auc: 0.9978
# Saved custom checkpoint for epoch 27.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9997749924659729, 0.9992499947547913]
#
#
# Epoch 00027: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/27epoch.h5
# Epoch 28/100
# Learning rate:  0.009999999776482582
# 13/13 [==============================] - 29s 2s/step - loss: 0.0174 - accuracy: 0.9946 - auc: 0.9999 - val_loss: 0.0360 - val_accuracy: 0.9900 - val_auc: 0.9979
# Saved custom checkpoint for epoch 28.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9998124837875366, 0.9992499947547913]
#
#
# Epoch 00028: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/28epoch.h5
# Epoch 29/100
# Learning rate:  0.003162277629598975
# 13/13 [==============================] - 29s 2s/step - loss: 0.0288 - accuracy: 0.9874 - auc: 0.9997 - val_loss: 0.0340 - val_accuracy: 0.9900 - val_auc: 0.9980
# Saved custom checkpoint for epoch 29.
# Best acc, val acc, auc, val auc: [0.9900000095367432, 0.9900000095367432, 0.9998249411582947, 0.9992499947547913]
#
#
# Epoch 00029: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/29epoch.h5
# Epoch 30/100
# Learning rate:  0.003162277629598975
# 13/13 [==============================] - 29s 2s/step - loss: 0.0222 - accuracy: 0.9936 - auc: 0.9998 - val_loss: 0.0347 - val_accuracy: 0.9900 - val_auc: 0.9980
# Saved custom checkpoint for epoch 30.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998592734336853, 0.9992499947547913]
#
#
# Epoch 00030: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/30epoch.h5
# Epoch 31/100
# Learning rate:  0.003162277629598975
# 13/13 [==============================] - 29s 2s/step - loss: 0.0303 - accuracy: 0.9880 - auc: 0.9997 - val_loss: 0.0362 - val_accuracy: 0.9900 - val_auc: 0.9979
# Saved custom checkpoint for epoch 31.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.999875009059906, 0.9992499947547913]
#
#
# Epoch 00031: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/31epoch.h5
# Epoch 32/100
# Learning rate:  0.003162277629598975
# 13/13 [==============================] - 29s 2s/step - loss: 0.0250 - accuracy: 0.9882 - auc: 0.9998 - val_loss: 0.0359 - val_accuracy: 0.9900 - val_auc: 0.9979
# Saved custom checkpoint for epoch 32.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.999884307384491, 0.9992499947547913]
#
#
# Epoch 00032: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/32epoch.h5
# Epoch 33/100
# Learning rate:  0.003162277629598975
# 13/13 [==============================] - 29s 2s/step - loss: 0.0232 - accuracy: 0.9928 - auc: 0.9998 - val_loss: 0.0350 - val_accuracy: 0.9900 - val_auc: 0.9980
# Saved custom checkpoint for epoch 33.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.999884307384491, 0.9992499947547913]
#
#
# Epoch 00033: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/33epoch.h5
# Epoch 34/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0204 - accuracy: 0.9937 - auc: 0.9999 - val_loss: 0.0344 - val_accuracy: 0.9900 - val_auc: 0.9980
# Saved custom checkpoint for epoch 34.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874068260193, 0.9992499947547913]
#
#
# Epoch 00034: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/34epoch.h5
# Epoch 35/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0169 - accuracy: 0.9985 - auc: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9900 - val_auc: 0.9980
# Saved custom checkpoint for epoch 35.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874068260193, 0.9992499947547913]
#
#
# Epoch 00035: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/35epoch.h5
# Epoch 36/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0186 - accuracy: 0.9964 - auc: 0.9999 - val_loss: 0.0352 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 36.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874068260193, 0.9992499947547913]
#
#
# Epoch 00036: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/36epoch.h5
# Epoch 37/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0213 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.0350 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 37.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874068260193, 0.9992499947547913]
#
#
# Epoch 00037: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/37epoch.h5
# Epoch 38/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0325 - accuracy: 0.9877 - auc: 0.9996 - val_loss: 0.0342 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 38.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00038: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/38epoch.h5
# Epoch 39/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 29s 2s/step - loss: 0.0249 - accuracy: 0.9946 - auc: 0.9998 - val_loss: 0.0342 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 39.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00039: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/39epoch.h5
# Epoch 40/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 29s 2s/step - loss: 0.0304 - accuracy: 0.9905 - auc: 0.9996 - val_loss: 0.0343 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 40.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00040: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/40epoch.h5
# Epoch 41/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 29s 2s/step - loss: 0.0176 - accuracy: 0.9956 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 41.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00041: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/41epoch.h5
# Epoch 42/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 29s 2s/step - loss: 0.0185 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 42.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00042: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/42epoch.h5
# Epoch 43/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 29s 2s/step - loss: 0.0199 - accuracy: 0.9964 - auc: 0.9999 - val_loss: 0.0343 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 43.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00043: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/43epoch.h5
# Epoch 44/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0196 - accuracy: 0.9984 - auc: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 44.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00044: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/44epoch.h5
# Epoch 45/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0154 - accuracy: 0.9987 - auc: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 45.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00045: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/45epoch.h5
# Epoch 46/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0186 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 46.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00046: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/46epoch.h5
# Epoch 47/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0180 - accuracy: 0.9973 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 47.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00047: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/47epoch.h5
# Epoch 48/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 29s 2s/step - loss: 0.0274 - accuracy: 0.9918 - auc: 0.9997 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 48.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00048: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/48epoch.h5
# Epoch 49/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 29s 2s/step - loss: 0.0183 - accuracy: 0.9987 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 49.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00049: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/49epoch.h5
# Epoch 50/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 29s 2s/step - loss: 0.0248 - accuracy: 0.9942 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 50.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00050: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/50epoch.h5
# Epoch 51/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 29s 2s/step - loss: 0.0217 - accuracy: 0.9942 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 51.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00051: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/51epoch.h5
# Epoch 52/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 29s 2s/step - loss: 0.0175 - accuracy: 0.9980 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 52.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00052: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/52epoch.h5
# Epoch 53/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 29s 2s/step - loss: 0.0204 - accuracy: 0.9935 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 53.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00053: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/53epoch.h5
# Epoch 54/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 29s 2s/step - loss: 0.0216 - accuracy: 0.9975 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 54.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00054: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/54epoch.h5
# Epoch 55/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 28s 2s/step - loss: 0.0188 - accuracy: 0.9974 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 55.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00055: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/55epoch.h5
# Epoch 56/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 29s 2s/step - loss: 0.0164 - accuracy: 0.9980 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 56.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00056: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/56epoch.h5
# Epoch 57/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 28s 2s/step - loss: 0.0207 - accuracy: 0.9953 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 57.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00057: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/57epoch.h5
# Epoch 58/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 28s 2s/step - loss: 0.0271 - accuracy: 0.9915 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 58.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00058: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/58epoch.h5
# Epoch 59/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0192 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 59.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00059: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/59epoch.h5
# Epoch 60/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0168 - accuracy: 0.9980 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 60.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00060: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/60epoch.h5
# Epoch 61/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0327 - accuracy: 0.9895 - auc: 0.9996 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 61.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00061: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/61epoch.h5
# Epoch 62/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0248 - accuracy: 0.9920 - auc: 0.9996 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 62.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00062: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/62epoch.h5
# Epoch 63/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0218 - accuracy: 0.9946 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 63.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00063: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/63epoch.h5
# Epoch 64/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0218 - accuracy: 0.9967 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 64.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00064: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/64epoch.h5
# Epoch 65/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0230 - accuracy: 0.9942 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 65.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00065: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/65epoch.h5
# Epoch 66/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0176 - accuracy: 0.9972 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 66.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00066: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/66epoch.h5
# Epoch 67/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 28s 2s/step - loss: 0.0160 - accuracy: 0.9985 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 67.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00067: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/67epoch.h5
# Epoch 68/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 29s 2s/step - loss: 0.0296 - accuracy: 0.9905 - auc: 0.9996 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 68.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00068: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/68epoch.h5
# Epoch 69/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0237 - accuracy: 0.9901 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 69.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00069: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/69epoch.h5
# Epoch 70/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0173 - accuracy: 0.9968 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 70.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00070: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/70epoch.h5
# Epoch 71/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0231 - accuracy: 0.9920 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 71.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00071: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/71epoch.h5
# Epoch 72/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0230 - accuracy: 0.9947 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 72.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00072: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/72epoch.h5
# Epoch 73/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0230 - accuracy: 0.9946 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 73.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00073: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/73epoch.h5
# Epoch 74/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0189 - accuracy: 0.9978 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 74.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00074: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/74epoch.h5
# Epoch 75/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0220 - accuracy: 0.9947 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 75.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00075: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/75epoch.h5
# Epoch 76/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0190 - accuracy: 0.9968 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 76.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00076: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/76epoch.h5
# Epoch 77/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0219 - accuracy: 0.9959 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 77.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00077: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/77epoch.h5
# Epoch 78/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0252 - accuracy: 0.9937 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 78.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00078: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/78epoch.h5
# Epoch 79/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0204 - accuracy: 0.9942 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 79.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00079: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/79epoch.h5
# Epoch 80/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0135 - accuracy: 0.9991 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 80.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00080: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/80epoch.h5
# Epoch 81/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 29s 2s/step - loss: 0.0228 - accuracy: 0.9951 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 81.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00081: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/81epoch.h5
# Epoch 82/100
# Learning rate:  4.999999987376214e-08
# 13/13 [==============================] - 29s 2s/step - loss: 0.0220 - accuracy: 0.9967 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 82.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00082: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/82epoch.h5
# Epoch 83/100
# Learning rate:  5.000000058430488e-09
# 13/13 [==============================] - 29s 2s/step - loss: 0.0199 - accuracy: 0.9956 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 83.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00083: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/83epoch.h5
# Epoch 84/100
# Learning rate:  4.999999969612646e-10
# 13/13 [==============================] - 29s 2s/step - loss: 0.0220 - accuracy: 0.9937 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 84.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00084: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/84epoch.h5
# Epoch 85/100
# Learning rate:  4.999999858590343e-11
# 13/13 [==============================] - 29s 2s/step - loss: 0.0230 - accuracy: 0.9957 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 85.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00085: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/85epoch.h5
# Epoch 86/100
# Learning rate:  4.999999719812465e-12
# 13/13 [==============================] - 29s 2s/step - loss: 0.0175 - accuracy: 0.9966 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 86.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00086: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/86epoch.h5
# Epoch 87/100
# Learning rate:  4.999999546340118e-13
# 13/13 [==============================] - 29s 2s/step - loss: 0.0230 - accuracy: 0.9939 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 87.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00087: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/87epoch.h5
# Epoch 88/100
# Learning rate:  4.9999994379199e-14
# 13/13 [==============================] - 29s 2s/step - loss: 0.0170 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 88.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00088: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/88epoch.h5
# Epoch 89/100
# Learning rate:  4.999999573445172e-15
# 13/13 [==============================] - 29s 2s/step - loss: 0.0190 - accuracy: 0.9942 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 89.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00089: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/89epoch.h5
# Epoch 90/100
# Learning rate:  4.999999488741877e-16
# 13/13 [==============================] - 29s 2s/step - loss: 0.0240 - accuracy: 0.9937 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 90.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00090: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/90epoch.h5
# Epoch 91/100
# Learning rate:  4.999999488741877e-17
# 13/13 [==============================] - 29s 2s/step - loss: 0.0159 - accuracy: 0.9968 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 91.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00091: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/91epoch.h5
# Epoch 92/100
# Learning rate:  4.999999422567428e-18
# 13/13 [==============================] - 29s 2s/step - loss: 0.0157 - accuracy: 0.9974 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 92.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00092: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/92epoch.h5
# Epoch 93/100
# Learning rate:  4.999999505285489e-19
# 13/13 [==============================] - 29s 2s/step - loss: 0.0173 - accuracy: 0.9975 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 93.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00093: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/93epoch.h5
# Epoch 94/100
# Learning rate:  4.9999997120806425e-20
# 13/13 [==============================] - 29s 2s/step - loss: 0.0347 - accuracy: 0.9877 - auc: 0.9993 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 94.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00094: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/94epoch.h5
# Epoch 95/100
# Learning rate:  4.999999841327613e-21
# 13/13 [==============================] - 29s 2s/step - loss: 0.0306 - accuracy: 0.9888 - auc: 0.9996 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 95.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00095: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/95epoch.h5
# Epoch 96/100
# Learning rate:  4.999999841327613e-22
# 13/13 [==============================] - 29s 2s/step - loss: 0.0254 - accuracy: 0.9940 - auc: 0.9998 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 96.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00096: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/96epoch.h5
# Epoch 97/100
# Learning rate:  4.9999998413276127e-23
# 13/13 [==============================] - 29s 2s/step - loss: 0.0182 - accuracy: 0.9971 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 97.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00097: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/97epoch.h5
# Epoch 98/100
# Learning rate:  4.999999841327613e-24
# 13/13 [==============================] - 28s 2s/step - loss: 0.0138 - accuracy: 0.9980 - auc: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 98.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00098: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/98epoch.h5
# Epoch 99/100
# Learning rate:  4.999999999099794e-25
# 13/13 [==============================] - 28s 2s/step - loss: 0.0176 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 99.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00099: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/99epoch.h5
# Epoch 100/100
# Learning rate:  5.000000097707407e-26
# 13/13 [==============================] - 28s 2s/step - loss: 0.0331 - accuracy: 0.9854 - auc: 0.9994 - val_loss: 0.0341 - val_accuracy: 0.9900 - val_auc: 0.9981
# Saved custom checkpoint for epoch 100.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 0.9900000095367432, 0.9998874664306641, 0.9992499947547913]
#
#
# Epoch 00100: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Hybrid/100epoch.h5
# Best Train Accuracy: 0.9950000047683716
# Best Val Accuracy: 0.9900000095367432
# Best Train AUC: 0.9998874664306641
# Best Val AUC 0.9992499947547913

# %% [markdown]
# If later we want to continue the training, to load the model's and optimizer's state, we can reconstruct and recompile the model (basically re-running the code up until before the training) and then running this code in a new cell:
#
# ```
# checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
# ```
#
# After that, we can do the training like usual but remember to change the `initial_epoch` argument of Keras' model `fit()` method to the number of epoch of the last training session.
#
# For example, if the previous training session ends on epoch 195, then continue the training with this code:
#
# ```
# last_epoch = 195
#
# H = model.fit(X_train, tf.keras.utils.to_categorical(Y_train),
#               initial_epoch=last_epoch,
#               batch_size=BATCH_SIZE,
#               epochs=EPOCHS,
#               validation_data=(X_test, tf.keras.utils.to_categorical(Y_test)),
#               shuffle=True,
#               callbacks=callback_list)
# ```

# %% [markdown]
# # 5. Fully Quantum QCNN

# %% [markdown]
# In this fifth section, we will show how to build a QCNN model with quantum convolution followed by a quantum classifier (no classical layer at all). This is basically as simple as replacing the classical fully-connected layer of model in section **4** with a quantum classifier explained in section **3**.

# %% [markdown]
# Let's build a model with two quantum convolution layers, a max pooling layer, followed by a layer of quantum classifier.

# %% [markdown]
# ## Build the Model

# %%
n_qubits = 2

# Construct the observable for the quantum classifier
qubits = cirq.GridQubit.rect(1, n_qubits)
Z_0 = cirq.PauliString(cirq.Z(qubits[0]))
I_0 = cirq.PauliString(cirq.I(qubits[0]))
Z_1 = cirq.PauliString(cirq.Z(qubits[1]))
I_1 = cirq.PauliString(cirq.I(qubits[1]))
observables = [0.5*Z_0 + 0.5*I_0, -0.5*Z_1 + 0.5*I_1]  # equivalent to |0⟩⟨0|⊗|1⟩⟨1|, or, |0⟩⟨0| for the first qubit and |1⟩⟨1| for the second qubit

# %%
# Full size MNIST images as input with shape (28, 28, 1)
input_tensor = tf.keras.Input(shape=(28, 28, 1), dtype=tf.dtypes.float32, name='input')

drc_settings = {
    "n_qubits": [1],
    "n_layers": [1],
    "use_ent": [True],
    "use_terminal_ent": [True]
}

# Two quantum convolution layers
qconv_1 = QConv2D_DRC(1, (3,3), (2,2), drc_settings, 1, padding="valid").call(input_tensor)
qconv_2 = QConv2D_DRC(1, (3,3), (2,2), drc_settings, 2, padding="valid").call(qconv_1)

# A max pooling layer
pool = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding="valid")(qconv_2)

# Flatten the tensor
flat = tf.keras.layers.Flatten()(pool)

# A layer of quantum classifier
quantum_classifier = ReUploadingPQC(n_qubits, 1, flat.shape[-1], use_entanglement=True, use_terminal_entanglement=True, observables=observables)(flat)

model = tf.keras.Model(inputs=[input_tensor], outputs=quantum_classifier)

# %%
model.summary()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# tf.compat.v1.pad_14 (TFOpLambda (None, 29, 29, 1)    0           input[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1729 ( (None, 29, 29)       0           tf.compat.v1.pad_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1730 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1731 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1732 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1733 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1734 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1735 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1736 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1737 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1738 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1739 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1740 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1741 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1742 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1743 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1744 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1745 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1746 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1747 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1748 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1749 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1750 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1751 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1752 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1753 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1754 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1755 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1756 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1757 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1758 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1759 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1760 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1761 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1762 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1763 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1764 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1765 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1766 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1767 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1768 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1769 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1770 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1771 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1772 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1773 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1774 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1775 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1776 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1777 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1778 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1779 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1780 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1781 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1782 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1783 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1784 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1785 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1786 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1787 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1788 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1789 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1790 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1791 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1792 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1793 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1794 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1795 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1796 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1797 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1798 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1799 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1800 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1801 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1802 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1803 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1804 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1805 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1806 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1807 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1808 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1809 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1810 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1811 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1812 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1813 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1814 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1815 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1816 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1817 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1818 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1819 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1820 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1821 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1822 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1823 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1824 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1825 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1826 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1827 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1828 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1829 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1830 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1831 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1832 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1833 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1834 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1835 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1836 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1837 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1838 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1839 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1840 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1841 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1842 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1843 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1844 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1845 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1846 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1847 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1848 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1849 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1850 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1851 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1852 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1853 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1854 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1855 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1856 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1857 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1858 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1859 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1860 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1861 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1862 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1863 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1864 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1865 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1866 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1867 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1868 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1869 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1870 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1871 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1872 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1873 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1874 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1875 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1876 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1877 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1878 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1879 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1880 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1881 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1882 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1883 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1884 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1885 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1886 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1887 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1888 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1889 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1890 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1891 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1892 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1893 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1894 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1895 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1896 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1897 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1898 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1899 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1900 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1901 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1902 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1903 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1904 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1905 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1906 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1907 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1908 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1909 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1910 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1911 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1912 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1913 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1914 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1915 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1916 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1917 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1918 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1919 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1920 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1921 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1922 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1923 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1924 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1925 ( (None, 3, 3)         0           tf.__operators__.getitem_1729[0][
# __________________________________________________________________________________________________
# QConv_Operation_1_1_1 (ReUpload (None, 1)            18          tf.__operators__.getitem_1730[0][
#                                                                  tf.__operators__.getitem_1731[0][
#                                                                  tf.__operators__.getitem_1732[0][
#                                                                  tf.__operators__.getitem_1733[0][
#                                                                  tf.__operators__.getitem_1734[0][
#                                                                  tf.__operators__.getitem_1735[0][
#                                                                  tf.__operators__.getitem_1736[0][
#                                                                  tf.__operators__.getitem_1737[0][
#                                                                  tf.__operators__.getitem_1738[0][
#                                                                  tf.__operators__.getitem_1739[0][
#                                                                  tf.__operators__.getitem_1740[0][
#                                                                  tf.__operators__.getitem_1741[0][
#                                                                  tf.__operators__.getitem_1742[0][
#                                                                  tf.__operators__.getitem_1743[0][
#                                                                  tf.__operators__.getitem_1744[0][
#                                                                  tf.__operators__.getitem_1745[0][
#                                                                  tf.__operators__.getitem_1746[0][
#                                                                  tf.__operators__.getitem_1747[0][
#                                                                  tf.__operators__.getitem_1748[0][
#                                                                  tf.__operators__.getitem_1749[0][
#                                                                  tf.__operators__.getitem_1750[0][
#                                                                  tf.__operators__.getitem_1751[0][
#                                                                  tf.__operators__.getitem_1752[0][
#                                                                  tf.__operators__.getitem_1753[0][
#                                                                  tf.__operators__.getitem_1754[0][
#                                                                  tf.__operators__.getitem_1755[0][
#                                                                  tf.__operators__.getitem_1756[0][
#                                                                  tf.__operators__.getitem_1757[0][
#                                                                  tf.__operators__.getitem_1758[0][
#                                                                  tf.__operators__.getitem_1759[0][
#                                                                  tf.__operators__.getitem_1760[0][
#                                                                  tf.__operators__.getitem_1761[0][
#                                                                  tf.__operators__.getitem_1762[0][
#                                                                  tf.__operators__.getitem_1763[0][
#                                                                  tf.__operators__.getitem_1764[0][
#                                                                  tf.__operators__.getitem_1765[0][
#                                                                  tf.__operators__.getitem_1766[0][
#                                                                  tf.__operators__.getitem_1767[0][
#                                                                  tf.__operators__.getitem_1768[0][
#                                                                  tf.__operators__.getitem_1769[0][
#                                                                  tf.__operators__.getitem_1770[0][
#                                                                  tf.__operators__.getitem_1771[0][
#                                                                  tf.__operators__.getitem_1772[0][
#                                                                  tf.__operators__.getitem_1773[0][
#                                                                  tf.__operators__.getitem_1774[0][
#                                                                  tf.__operators__.getitem_1775[0][
#                                                                  tf.__operators__.getitem_1776[0][
#                                                                  tf.__operators__.getitem_1777[0][
#                                                                  tf.__operators__.getitem_1778[0][
#                                                                  tf.__operators__.getitem_1779[0][
#                                                                  tf.__operators__.getitem_1780[0][
#                                                                  tf.__operators__.getitem_1781[0][
#                                                                  tf.__operators__.getitem_1782[0][
#                                                                  tf.__operators__.getitem_1783[0][
#                                                                  tf.__operators__.getitem_1784[0][
#                                                                  tf.__operators__.getitem_1785[0][
#                                                                  tf.__operators__.getitem_1786[0][
#                                                                  tf.__operators__.getitem_1787[0][
#                                                                  tf.__operators__.getitem_1788[0][
#                                                                  tf.__operators__.getitem_1789[0][
#                                                                  tf.__operators__.getitem_1790[0][
#                                                                  tf.__operators__.getitem_1791[0][
#                                                                  tf.__operators__.getitem_1792[0][
#                                                                  tf.__operators__.getitem_1793[0][
#                                                                  tf.__operators__.getitem_1794[0][
#                                                                  tf.__operators__.getitem_1795[0][
#                                                                  tf.__operators__.getitem_1796[0][
#                                                                  tf.__operators__.getitem_1797[0][
#                                                                  tf.__operators__.getitem_1798[0][
#                                                                  tf.__operators__.getitem_1799[0][
#                                                                  tf.__operators__.getitem_1800[0][
#                                                                  tf.__operators__.getitem_1801[0][
#                                                                  tf.__operators__.getitem_1802[0][
#                                                                  tf.__operators__.getitem_1803[0][
#                                                                  tf.__operators__.getitem_1804[0][
#                                                                  tf.__operators__.getitem_1805[0][
#                                                                  tf.__operators__.getitem_1806[0][
#                                                                  tf.__operators__.getitem_1807[0][
#                                                                  tf.__operators__.getitem_1808[0][
#                                                                  tf.__operators__.getitem_1809[0][
#                                                                  tf.__operators__.getitem_1810[0][
#                                                                  tf.__operators__.getitem_1811[0][
#                                                                  tf.__operators__.getitem_1812[0][
# ...
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1951 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1952 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1953 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1954 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1955 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1956 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1957 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1958 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1959 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1960 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1961 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1962 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1963 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1964 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1965 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1966 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1967 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1968 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1969 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1970 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1971 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1972 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1973 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1974 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1975 ( (None, 3, 3)         0           tf.__operators__.getitem_1926[0][
# __________________________________________________________________________________________________
# QConv_Operation_2_1_1 (ReUpload (None, 1)            18          tf.__operators__.getitem_1927[0][
#                                                                  tf.__operators__.getitem_1928[0][
#                                                                  tf.__operators__.getitem_1929[0][
#                                                                  tf.__operators__.getitem_1930[0][
#                                                                  tf.__operators__.getitem_1931[0][
#                                                                  tf.__operators__.getitem_1932[0][
#                                                                  tf.__operators__.getitem_1933[0][
#                                                                  tf.__operators__.getitem_1934[0][
#                                                                  tf.__operators__.getitem_1935[0][
#                                                                  tf.__operators__.getitem_1936[0][
#                                                                  tf.__operators__.getitem_1937[0][
#                                                                  tf.__operators__.getitem_1938[0][
#                                                                  tf.__operators__.getitem_1939[0][
#                                                                  tf.__operators__.getitem_1940[0][
#                                                                  tf.__operators__.getitem_1941[0][
#                                                                  tf.__operators__.getitem_1942[0][
#                                                                  tf.__operators__.getitem_1943[0][
#                                                                  tf.__operators__.getitem_1944[0][
#                                                                  tf.__operators__.getitem_1945[0][
#                                                                  tf.__operators__.getitem_1946[0][
#                                                                  tf.__operators__.getitem_1947[0][
#                                                                  tf.__operators__.getitem_1948[0][
#                                                                  tf.__operators__.getitem_1949[0][
#                                                                  tf.__operators__.getitem_1950[0][
#                                                                  tf.__operators__.getitem_1951[0][
#                                                                  tf.__operators__.getitem_1952[0][
#                                                                  tf.__operators__.getitem_1953[0][
#                                                                  tf.__operators__.getitem_1954[0][
#                                                                  tf.__operators__.getitem_1955[0][
#                                                                  tf.__operators__.getitem_1956[0][
#                                                                  tf.__operators__.getitem_1957[0][
#                                                                  tf.__operators__.getitem_1958[0][
#                                                                  tf.__operators__.getitem_1959[0][
#                                                                  tf.__operators__.getitem_1960[0][
#                                                                  tf.__operators__.getitem_1961[0][
#                                                                  tf.__operators__.getitem_1962[0][
#                                                                  tf.__operators__.getitem_1963[0][
#                                                                  tf.__operators__.getitem_1964[0][
#                                                                  tf.__operators__.getitem_1965[0][
#                                                                  tf.__operators__.getitem_1966[0][
#                                                                  tf.__operators__.getitem_1967[0][
#                                                                  tf.__operators__.getitem_1968[0][
#                                                                  tf.__operators__.getitem_1969[0][
#                                                                  tf.__operators__.getitem_1970[0][
#                                                                  tf.__operators__.getitem_1971[0][
#                                                                  tf.__operators__.getitem_1972[0][
#                                                                  tf.__operators__.getitem_1973[0][
#                                                                  tf.__operators__.getitem_1974[0][
#                                                                  tf.__operators__.getitem_1975[0][
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 49)           0           QConv_Operation_2_1_1[0][0]
#                                                                  QConv_Operation_2_1_1[1][0]
#                                                                  QConv_Operation_2_1_1[2][0]
#                                                                  QConv_Operation_2_1_1[3][0]
#                                                                  QConv_Operation_2_1_1[4][0]
#                                                                  QConv_Operation_2_1_1[5][0]
#                                                                  QConv_Operation_2_1_1[6][0]
#                                                                  QConv_Operation_2_1_1[7][0]
#                                                                  QConv_Operation_2_1_1[8][0]
#                                                                  QConv_Operation_2_1_1[9][0]
#                                                                  QConv_Operation_2_1_1[10][0]
#                                                                  QConv_Operation_2_1_1[11][0]
#                                                                  QConv_Operation_2_1_1[12][0]
#                                                                  QConv_Operation_2_1_1[13][0]
#                                                                  QConv_Operation_2_1_1[14][0]
#                                                                  QConv_Operation_2_1_1[15][0]
#                                                                  QConv_Operation_2_1_1[16][0]
#                                                                  QConv_Operation_2_1_1[17][0]
#                                                                  QConv_Operation_2_1_1[18][0]
#                                                                  QConv_Operation_2_1_1[19][0]
#                                                                  QConv_Operation_2_1_1[20][0]
#                                                                  QConv_Operation_2_1_1[21][0]
#                                                                  QConv_Operation_2_1_1[22][0]
#                                                                  QConv_Operation_2_1_1[23][0]
#                                                                  QConv_Operation_2_1_1[24][0]
#                                                                  QConv_Operation_2_1_1[25][0]
#                                                                  QConv_Operation_2_1_1[26][0]
#                                                                  QConv_Operation_2_1_1[27][0]
#                                                                  QConv_Operation_2_1_1[28][0]
#                                                                  QConv_Operation_2_1_1[29][0]
#                                                                  QConv_Operation_2_1_1[30][0]
#                                                                  QConv_Operation_2_1_1[31][0]
#                                                                  QConv_Operation_2_1_1[32][0]
#                                                                  QConv_Operation_2_1_1[33][0]
#                                                                  QConv_Operation_2_1_1[34][0]
#                                                                  QConv_Operation_2_1_1[35][0]
#                                                                  QConv_Operation_2_1_1[36][0]
#                                                                  QConv_Operation_2_1_1[37][0]
#                                                                  QConv_Operation_2_1_1[38][0]
#                                                                  QConv_Operation_2_1_1[39][0]
#                                                                  QConv_Operation_2_1_1[40][0]
#                                                                  QConv_Operation_2_1_1[41][0]
#                                                                  QConv_Operation_2_1_1[42][0]
#                                                                  QConv_Operation_2_1_1[43][0]
#                                                                  QConv_Operation_2_1_1[44][0]
#                                                                  QConv_Operation_2_1_1[45][0]
#                                                                  QConv_Operation_2_1_1[46][0]
#                                                                  QConv_Operation_2_1_1[47][0]
#                                                                  QConv_Operation_2_1_1[48][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 7, 7, 1)      0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 1)      0           reshape_15[0][0]
# __________________________________________________________________________________________________
# flatten_253 (Flatten)           (None, 9)            0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# re-uploading_PQC (ReUploadingPQ (None, 2)            36          flatten_253[0][0]
# ==================================================================================================
# Total params: 72
# Trainable params: 72
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# For this example, we again use the MSE loss function.

# %%
# Training parameters
BATCH_SIZE = 32
EPOCHS = 100

# Print parameters for sanity check
print("Batch size, epochs:", BATCH_SIZE, EPOCHS)

# Optimizer with learning rate scheduler
opt_adam = tf.keras.optimizers.Adam(lr=lr_schedule(0, lr_init=0.1))

# Compile the model with MSE loss
model.compile(loss='mse',
              optimizer=opt_adam,
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
# Out:
# Batch size, epochs: 32 100
# Learning rate:  0.1

# %%
# The directory on where we want to save the model
checkpoint_dir = main_dir + '/Fully Quantum'

# Initialize callbacks
# Let's use both callbacks that we have prepared just in case
cp_1 = CustomCallback(checkpoint_dir)
cp_2 = checkpoint_save_weights_only(checkpoint_dir)

# A list of callbacks to be passed on the Keras' model training API
callback_list = [cp_1, cp_2, lr_reducer, lr_scheduler]

# %% [markdown]
# ## Train the Model

# %%
last_epoch = 0

# Train the model
H = model.fit(X_train, tf.keras.utils.to_categorical(Y_train), initial_epoch=last_epoch,
              batch_size=BATCH_SIZE,
              epochs=EPOCHS,
              validation_data=(X_test, tf.keras.utils.to_categorical(Y_test)),
              shuffle=True,
              callbacks=callback_list)

# Print and plot the best metrics obtained during the training
print("Best Train Accuracy:", max(H.history['accuracy']))
print("Best Val Accuracy:", max(H.history['val_accuracy']))
print("Best Train AUC:", max(H.history['auc']))
print("Best Val AUC", max(H.history['val_auc']))

plt.plot(H.history['accuracy'], label='Train Accuracy')
plt.plot(H.history['val_accuracy'], label='Val Accuracy')
plt.plot(H.history['auc'], label='Train AUC')
plt.plot(H.history['val_auc'], label='Val AUC')

plt.xlabel('Epoch')

plt.legend()
plt.show()
# Out:
# Epoch 1/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 141s 4s/step - loss: 0.3128 - accuracy: 0.5101 - auc: 0.5083 - val_loss: 0.2925 - val_accuracy: 0.5000 - val_auc: 0.6538
# Saved custom checkpoint for epoch 1.
# Best acc, val acc, auc, val auc: [0.5099999904632568, 0.5, 0.5130499601364136, 0.6538249850273132]
#
#
# Epoch 00001: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/01epoch.h5
# Epoch 2/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 30s 2s/step - loss: 0.2553 - accuracy: 0.6044 - auc: 0.6008 - val_loss: 0.0775 - val_accuracy: 0.9050 - val_auc: 0.9755
# Saved custom checkpoint for epoch 2.
# Best acc, val acc, auc, val auc: [0.7149999737739563, 0.9049999713897705, 0.7424718737602234, 0.9755125045776367]
#
#
# Epoch 00002: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/02epoch.h5
# Epoch 3/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0412 - accuracy: 0.9827 - auc: 0.9943 - val_loss: 0.0084 - val_accuracy: 1.0000 - val_auc: 1.0000
# Saved custom checkpoint for epoch 3.
# Best acc, val acc, auc, val auc: [0.987500011920929, 1.0, 0.996874988079071, 1.0000001192092896]
#
#
# Epoch 00003: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/03epoch.h5
# Epoch 4/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0201 - accuracy: 0.9817 - auc: 0.9938 - val_loss: 0.0306 - val_accuracy: 0.9850 - val_auc: 0.9920
# Saved custom checkpoint for epoch 4.
# Best acc, val acc, auc, val auc: [0.987500011920929, 1.0, 0.996874988079071, 1.0000001192092896]
#
#
# Epoch 00004: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/04epoch.h5
# Epoch 5/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 30s 2s/step - loss: 0.0266 - accuracy: 0.9862 - auc: 0.9905 - val_loss: 0.0090 - val_accuracy: 0.9950 - val_auc: 0.9989
# Saved custom checkpoint for epoch 5.
# Best acc, val acc, auc, val auc: [0.987500011920929, 1.0, 0.9969093799591064, 1.0000001192092896]
#
#
# Epoch 00005: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/05epoch.h5
# Epoch 6/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0185 - accuracy: 0.9846 - auc: 0.9935 - val_loss: 0.0060 - val_accuracy: 0.9900 - val_auc: 0.9999
# Saved custom checkpoint for epoch 6.
# Best acc, val acc, auc, val auc: [0.987500011920929, 1.0, 0.9969093799591064, 1.0000001192092896]
#
#
# Epoch 00006: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/06epoch.h5
# Epoch 7/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0126 - accuracy: 0.9910 - auc: 0.9956 - val_loss: 0.0028 - val_accuracy: 1.0000 - val_auc: 1.0000
# Saved custom checkpoint for epoch 7.
# Best acc, val acc, auc, val auc: [0.9925000071525574, 1.0, 0.9980843663215637, 1.0000001192092896]
#
#
# Epoch 00007: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/07epoch.h5
# Epoch 8/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0035 - accuracy: 0.9980 - auc: 0.9993 - val_loss: 0.0022 - val_accuracy: 1.0000 - val_auc: 1.0000
# Saved custom checkpoint for epoch 8.
# Best acc, val acc, auc, val auc: [0.9950000047683716, 1.0, 0.9980843663215637, 1.0000001192092896]
#
#
# Epoch 00008: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/08epoch.h5
# Epoch 9/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0038 - accuracy: 0.9982 - auc: 0.9987 - val_loss: 0.0035 - val_accuracy: 0.9950 - val_auc: 1.0000
# Saved custom checkpoint for epoch 9.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00009: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/09epoch.h5
# Epoch 10/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0027 - accuracy: 0.9988 - auc: 0.9984 - val_loss: 0.0051 - val_accuracy: 0.9950 - val_auc: 0.9998
# Saved custom checkpoint for epoch 10.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00010: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/10epoch.h5
# Epoch 11/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0035 - accuracy: 0.9958 - auc: 0.9981 - val_loss: 0.0029 - val_accuracy: 0.9950 - val_auc: 1.0000
# Saved custom checkpoint for epoch 11.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00011: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/11epoch.h5
# Epoch 12/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 30s 2s/step - loss: 0.0024 - accuracy: 0.9985 - auc: 0.9980 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 1.0000
# Saved custom checkpoint for epoch 12.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00012: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/12epoch.h5
# Epoch 13/100
# Learning rate:  0.10000000149011612
# 13/13 [==============================] - 31s 2s/step - loss: 0.0021 - accuracy: 0.9988 - auc: 0.9983 - val_loss: 0.0049 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 13.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00013: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/13epoch.h5
# Epoch 14/100
# Learning rate:  0.03162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0078 - accuracy: 0.9927 - auc: 0.9926 - val_loss: 0.0046 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 14.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00014: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/14epoch.h5
# Epoch 15/100
# Learning rate:  0.03162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0078 - accuracy: 0.9927 - auc: 0.9926 - val_loss: 0.0044 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 15.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00015: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/15epoch.h5
# Epoch 16/100
# Learning rate:  0.03162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0012 - accuracy: 0.9993 - auc: 0.9990 - val_loss: 0.0040 - val_accuracy: 0.9950 - val_auc: 1.0000
# Saved custom checkpoint for epoch 16.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00016: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/16epoch.h5
# Epoch 17/100
# Learning rate:  0.03162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0012 - accuracy: 0.9993 - auc: 0.9992 - val_loss: 0.0042 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 17.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00017: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/17epoch.h5
# Epoch 18/100
# Learning rate:  0.03162277862429619
# 13/13 [==============================] - 31s 2s/step - loss: 0.0016 - accuracy: 0.9988 - auc: 0.9990 - val_loss: 0.0043 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 18.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00018: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/18epoch.h5
# Epoch 19/100
# Learning rate:  0.010000000707805157
# 13/13 [==============================] - 30s 2s/step - loss: 0.0016 - accuracy: 0.9988 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 19.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9982656240463257, 1.0000001192092896]
#
#
# Epoch 00019: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/19epoch.h5
# Epoch 20/100
# Learning rate:  0.010000000707805157
# 13/13 [==============================] - 30s 2s/step - loss: 0.0021 - accuracy: 0.9982 - auc: 0.9990 - val_loss: 0.0042 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 20.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9985531568527222, 1.0000001192092896]
#
#
# Epoch 00020: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/20epoch.h5
# Epoch 21/100
# Learning rate:  0.010000000707805157
# 13/13 [==============================] - 30s 2s/step - loss: 0.0043 - accuracy: 0.9961 - auc: 0.9979 - val_loss: 0.0042 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 21.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9987999796867371, 1.0000001192092896]
#
#
# Epoch 00021: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/21epoch.h5
# Epoch 22/100
# Learning rate:  0.010000000707805157
# 13/13 [==============================] - 30s 2s/step - loss: 0.0042 - accuracy: 0.9961 - auc: 0.9980 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 22.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988500475883484, 1.0000001192092896]
#
#
# Epoch 00022: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/22epoch.h5
# Epoch 23/100
# Learning rate:  0.010000000707805157
# 13/13 [==============================] - 30s 2s/step - loss: 0.0042 - accuracy: 0.9961 - auc: 0.9980 - val_loss: 0.0042 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 23.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988500475883484, 1.0000001192092896]
#
#
# Epoch 00023: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/23epoch.h5
# Epoch 24/100
# Learning rate:  0.003162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 24.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988500475883484, 1.0000001192092896]
#
#
# Epoch 00024: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/24epoch.h5
# Epoch 25/100
# Learning rate:  0.003162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0025 - accuracy: 0.9978 - auc: 0.9988 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 25.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988500475883484, 1.0000001192092896]
#
#
# Epoch 00025: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/25epoch.h5
# Epoch 26/100
# Learning rate:  0.003162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0020 - accuracy: 0.9982 - auc: 0.9990 - val_loss: 0.0042 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 26.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988500475883484, 1.0000001192092896]
#
#
# Epoch 00026: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/26epoch.h5
# Epoch 27/100
# Learning rate:  0.003162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0035 - accuracy: 0.9968 - auc: 0.9982 - val_loss: 0.0042 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 27.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988500475883484, 1.0000001192092896]
#
#
# Epoch 00027: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/27epoch.h5
# Epoch 28/100
# Learning rate:  0.003162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0015 - accuracy: 0.9988 - auc: 0.9994 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 28.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988500475883484, 1.0000001192092896]
#
#
# Epoch 00028: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/28epoch.h5
# Epoch 29/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 30s 2s/step - loss: 0.0035 - accuracy: 0.9968 - auc: 0.9985 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 29.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9988999962806702, 1.0000001192092896]
#
#
# Epoch 00029: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/29epoch.h5
# Epoch 30/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 31s 2s/step - loss: 0.0012 - accuracy: 0.9990 - auc: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 30.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989030957221985, 1.0000001192092896]
#
#
# Epoch 00030: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/30epoch.h5
# Epoch 31/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 31s 2s/step - loss: 0.0042 - accuracy: 0.9961 - auc: 0.9983 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 31.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989030957221985, 1.0000001192092896]
#
#
# Epoch 00031: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/31epoch.h5
# Epoch 32/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 31s 2s/step - loss: 0.0010 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 32.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989030957221985, 1.0000001192092896]
#
#
# Epoch 00032: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/32epoch.h5
# Epoch 33/100
# Learning rate:  0.0010000000474974513
# 13/13 [==============================] - 31s 2s/step - loss: 0.0035 - accuracy: 0.9968 - auc: 0.9985 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 33.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989030957221985, 1.0000001192092896]
#
#
# Epoch 00033: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/33epoch.h5
# Epoch 34/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 31s 2s/step - loss: 0.0025 - accuracy: 0.9978 - auc: 0.9991 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 34.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00034: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/34epoch.h5
# Epoch 35/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 31s 2s/step - loss: 0.0020 - accuracy: 0.9982 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 35.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00035: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/35epoch.h5
# Epoch 36/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 31s 2s/step - loss: 0.0042 - accuracy: 0.9961 - auc: 0.9981 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 36.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00036: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/36epoch.h5
# Epoch 37/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 0.0013 - accuracy: 0.9990 - auc: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 37.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00037: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/37epoch.h5
# Epoch 38/100
# Learning rate:  0.0003162277862429619
# 13/13 [==============================] - 30s 2s/step - loss: 8.6841e-04 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 38.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00038: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/38epoch.h5
# Epoch 39/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 30s 2s/step - loss: 0.0029 - accuracy: 0.9974 - auc: 0.9988 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 39.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00039: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/39epoch.h5
# Epoch 40/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 30s 2s/step - loss: 0.0019 - accuracy: 0.9985 - auc: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 40.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00040: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/40epoch.h5
# Epoch 41/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 30s 2s/step - loss: 0.0016 - accuracy: 0.9988 - auc: 0.9995 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 41.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00041: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/41epoch.h5
# Epoch 42/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 30s 2s/step - loss: 0.0013 - accuracy: 0.9990 - auc: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 42.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00042: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/42epoch.h5
# Epoch 43/100
# Learning rate:  0.00010000000474974513
# 13/13 [==============================] - 30s 2s/step - loss: 0.0053 - accuracy: 0.9949 - auc: 0.9979 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 43.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00043: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/43epoch.h5
# Epoch 44/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 30s 2s/step - loss: 0.0075 - accuracy: 0.9927 - auc: 0.9966 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 44.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00044: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/44epoch.h5
# Epoch 45/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 30s 2s/step - loss: 0.0053 - accuracy: 0.9949 - auc: 0.9979 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 45.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00045: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/45epoch.h5
# Epoch 46/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 30s 2s/step - loss: 6.9834e-04 - accuracy: 0.9996 - auc: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 46.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00046: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/46epoch.h5
# Epoch 47/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 30s 2s/step - loss: 0.0074 - accuracy: 0.9927 - auc: 0.9967 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 47.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00047: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/47epoch.h5
# Epoch 48/100
# Learning rate:  3.162277789670043e-05
# 13/13 [==============================] - 31s 2s/step - loss: 0.0026 - accuracy: 0.9978 - auc: 0.9989 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 48.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00048: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/48epoch.h5
# Epoch 49/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 31s 2s/step - loss: 0.0041 - accuracy: 0.9961 - auc: 0.9984 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 49.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00049: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/49epoch.h5
# Epoch 50/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 31s 2s/step - loss: 0.0042 - accuracy: 0.9961 - auc: 0.9983 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 50.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00050: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/50epoch.h5
# Epoch 51/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 30s 2s/step - loss: 0.0021 - accuracy: 0.9982 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 51.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00051: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/51epoch.h5
# Epoch 52/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 30s 2s/step - loss: 0.0052 - accuracy: 0.9949 - auc: 0.9981 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 52.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00052: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/52epoch.h5
# Epoch 53/100
# Learning rate:  1.0000000656873453e-05
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 53.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00053: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/53epoch.h5
# Epoch 54/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 30s 2s/step - loss: 0.0025 - accuracy: 0.9978 - auc: 0.9991 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 54.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00054: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/54epoch.h5
# Epoch 55/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 31s 2s/step - loss: 0.0025 - accuracy: 0.9978 - auc: 0.9990 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 55.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00055: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/55epoch.h5
# Epoch 56/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 30s 2s/step - loss: 0.0029 - accuracy: 0.9974 - auc: 0.9988 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 56.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00056: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/56epoch.h5
# Epoch 57/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 30s 2s/step - loss: 0.0035 - accuracy: 0.9968 - auc: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 57.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00057: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/57epoch.h5
# Epoch 58/100
# Learning rate:  3.1622778351447778e-06
# 13/13 [==============================] - 30s 2s/step - loss: 0.0075 - accuracy: 0.9927 - auc: 0.9968 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 58.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00058: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/58epoch.h5
# Epoch 59/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 31s 2s/step - loss: 0.0034 - accuracy: 0.9968 - auc: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 59.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00059: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/59epoch.h5
# Epoch 60/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 31s 2s/step - loss: 8.6800e-04 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 60.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00060: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/60epoch.h5
# Epoch 61/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 30s 2s/step - loss: 0.0074 - accuracy: 0.9927 - auc: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 61.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00061: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/61epoch.h5
# Epoch 62/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 30s 2s/step - loss: 0.0011 - accuracy: 0.9993 - auc: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 62.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00062: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/62epoch.h5
# Epoch 63/100
# Learning rate:  1.0000001111620804e-06
# 13/13 [==============================] - 30s 2s/step - loss: 0.0021 - accuracy: 0.9982 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 63.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00063: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/63epoch.h5
# Epoch 64/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0035 - accuracy: 0.9968 - auc: 0.9987 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 64.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00064: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/64epoch.h5
# Epoch 65/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0030 - accuracy: 0.9974 - auc: 0.9988 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 65.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00065: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/65epoch.h5
# Epoch 66/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0021 - accuracy: 0.9982 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 66.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00066: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/66epoch.h5
# Epoch 67/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 9.1039e-04 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 67.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00067: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/67epoch.h5
# Epoch 68/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0026 - accuracy: 0.9978 - auc: 0.9990 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 68.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00068: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/68epoch.h5
# Epoch 69/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 31s 2s/step - loss: 0.0011 - accuracy: 0.9993 - auc: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 69.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00069: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/69epoch.h5
# Epoch 70/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 31s 2s/step - loss: 0.0052 - accuracy: 0.9949 - auc: 0.9975 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 70.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00070: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/70epoch.h5
# Epoch 71/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 31s 2s/step - loss: 0.0053 - accuracy: 0.9949 - auc: 0.9978 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 71.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00071: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/71epoch.h5
# Epoch 72/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 31s 2s/step - loss: 0.0013 - accuracy: 0.9990 - auc: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 72.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00072: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/72epoch.h5
# Epoch 73/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 31s 2s/step - loss: 0.0074 - accuracy: 0.9927 - auc: 0.9972 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 73.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00073: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/73epoch.h5
# Epoch 74/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0011 - accuracy: 0.9993 - auc: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 74.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00074: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/74epoch.h5
# Epoch 75/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0011 - accuracy: 0.9993 - auc: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 75.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00075: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/75epoch.h5
# Epoch 76/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0025 - accuracy: 0.9978 - auc: 0.9990 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 76.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00076: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/76epoch.h5
# Epoch 77/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 9.0248e-04 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 77.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00077: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/77epoch.h5
# Epoch 78/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 78.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00078: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/78epoch.h5
# Epoch 79/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9994 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 79.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00079: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/79epoch.h5
# Epoch 80/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0041 - accuracy: 0.9961 - auc: 0.9981 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 80.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00080: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/80epoch.h5
# Epoch 81/100
# Learning rate:  4.999999987376214e-07
# 13/13 [==============================] - 30s 2s/step - loss: 0.0019 - accuracy: 0.9985 - auc: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 81.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00081: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/81epoch.h5
# Epoch 82/100
# Learning rate:  4.999999987376214e-08
# 13/13 [==============================] - 30s 2s/step - loss: 0.0013 - accuracy: 0.9990 - auc: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 82.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00082: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/82epoch.h5
# Epoch 83/100
# Learning rate:  5.000000058430488e-09
# 13/13 [==============================] - 30s 2s/step - loss: 0.0074 - accuracy: 0.9927 - auc: 0.9969 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 83.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00083: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/83epoch.h5
# Epoch 84/100
# Learning rate:  4.999999969612646e-10
# 13/13 [==============================] - 30s 2s/step - loss: 0.0074 - accuracy: 0.9927 - auc: 0.9967 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 84.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00084: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/84epoch.h5
# Epoch 85/100
# Learning rate:  4.999999858590343e-11
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9994 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 85.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00085: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/85epoch.h5
# Epoch 86/100
# Learning rate:  4.999999719812465e-12
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 86.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00086: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/86epoch.h5
# Epoch 87/100
# Learning rate:  4.999999546340118e-13
# 13/13 [==============================] - 30s 2s/step - loss: 0.0013 - accuracy: 0.9990 - auc: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 87.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00087: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/87epoch.h5
# Epoch 88/100
# Learning rate:  4.9999994379199e-14
# 13/13 [==============================] - 31s 2s/step - loss: 0.0034 - accuracy: 0.9968 - auc: 0.9985 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 88.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00088: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/88epoch.h5
# Epoch 89/100
# Learning rate:  4.999999573445172e-15
# 13/13 [==============================] - 30s 2s/step - loss: 0.0029 - accuracy: 0.9974 - auc: 0.9988 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 89.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00089: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/89epoch.h5
# Epoch 90/100
# Learning rate:  4.999999488741877e-16
# 13/13 [==============================] - 30s 2s/step - loss: 0.0022 - accuracy: 0.9982 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 90.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00090: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/90epoch.h5
# Epoch 91/100
# Learning rate:  4.999999488741877e-17
# 13/13 [==============================] - 30s 2s/step - loss: 0.0042 - accuracy: 0.9961 - auc: 0.9981 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 91.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00091: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/91epoch.h5
# Epoch 92/100
# Learning rate:  4.999999422567428e-18
# 13/13 [==============================] - 30s 2s/step - loss: 0.0011 - accuracy: 0.9993 - auc: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 92.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00092: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/92epoch.h5
# Epoch 93/100
# Learning rate:  4.999999505285489e-19
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 93.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00093: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/93epoch.h5
# Epoch 94/100
# Learning rate:  4.9999997120806425e-20
# 13/13 [==============================] - 30s 2s/step - loss: 0.0018 - accuracy: 0.9985 - auc: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 94.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00094: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/94epoch.h5
# Epoch 95/100
# Learning rate:  4.999999841327613e-21
# 13/13 [==============================] - 30s 2s/step - loss: 0.0022 - accuracy: 0.9982 - auc: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 95.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00095: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/95epoch.h5
# Epoch 96/100
# Learning rate:  4.999999841327613e-22
# 13/13 [==============================] - 30s 2s/step - loss: 0.0075 - accuracy: 0.9927 - auc: 0.9964 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 96.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00096: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/96epoch.h5
# Epoch 97/100
# Learning rate:  4.9999998413276127e-23
# 13/13 [==============================] - 30s 2s/step - loss: 6.8647e-04 - accuracy: 0.9996 - auc: 0.9998 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 97.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00097: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/97epoch.h5
# Epoch 98/100
# Learning rate:  4.999999841327613e-24
# 13/13 [==============================] - 30s 2s/step - loss: 0.0024 - accuracy: 0.9978 - auc: 0.9990 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 98.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00098: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/98epoch.h5
# Epoch 99/100
# Learning rate:  4.999999999099794e-25
# 13/13 [==============================] - 30s 2s/step - loss: 0.0011 - accuracy: 0.9993 - auc: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 99.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00099: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/99epoch.h5
# Epoch 100/100
# Learning rate:  5.000000097707407e-26
# 13/13 [==============================] - 30s 2s/step - loss: 0.0015 - accuracy: 0.9988 - auc: 0.9995 - val_loss: 0.0041 - val_accuracy: 0.9950 - val_auc: 0.9999
# Saved custom checkpoint for epoch 100.
# Best acc, val acc, auc, val auc: [0.9975000023841858, 1.0, 0.9989093542098999, 1.0000001192092896]
#
#
# Epoch 00100: saving model to /content/drive/My Drive/Projects/GSoC 2021/tutorials/Fully Quantum/100epoch.h5
# Best Train Accuracy: 0.9975000023841858
# Best Val Accuracy: 1.0
# Best Train AUC: 0.9989093542098999
# Best Val AUC 1.0000001192092896

# %% [markdown]
# # End
#
# That's it! Enjoy the package, and please let [me](mailto:eraraya-ricardo@qlab.itb.ac.id) know if you found any bugs in the tutorial.
#
# Thanks a lot for your interest in this package!
